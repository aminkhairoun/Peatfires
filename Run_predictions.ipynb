# %% [markdown]
# ## Libraries

# %%
import os, sys, glob
from osgeo import gdal, osr, ogr
import rasterio as rio
import netCDF4
import itertools, re
from datetime import datetime
import numpy as np
from joblib import Parallel, delayed
import io
import operator
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
import xgboost as xgb
from xgboost import dask as dxgb
import pickle
from sklearn.kernel_approximation import Nystroem
from sklearn.gaussian_process.kernels import Matern
import pyproj

# from dask import delayed, compute, distributed
import dask
import dask.dataframe as dd
from dask.distributed import Client, LocalCluster
from dask.diagnostics import ProgressBar
pbar = ProgressBar()
pbar.register()
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import Global_Functions
import Gdal_Functions

# %%
local_path = '/media/amin/STORAGE/STORAGE/OneDrive/PhD/Landsat_BA'
data = pd.read_csv(f'{local_path}/Siberia/PeatFire/BG_CC/data/Data_Emissions_Modelling.csv', index_col='Unnamed: 0')
clim = [
 'Tmax_terra',
 'Tmax_anomaly',
 'Tmin_terra',
 'Tmin_anomaly',
 'VPD_terra',
 'VPD_anomaly',
 'solar_down_terra',
 'solar_down_anomaly',
 'pdsi',
 'pdsi_anomaly',
 'cwd',
 'cwd_anomaly',
'moisture_terra',
 'moisture_anomaly',
 'duff_moisture',
 'finefuel_moisture',
 'FWI',
 'duff_moisture_anomaly',
 'finefuel_moisture_anomaly',
 'FWI_anomaly',
]

variables = ['post_NBR', 'post_NBR2','diff_NBR', 'diff_NBR2', 'FRP',
               'JD', 'BA_patch', 'duration', 'sand', 'silt', 'clay', 
                *clim,
               'LST', 'LST_anomaly_std', 'LST_persistence',
               'SOC', 'bog', 'fen', 'elevation', 'aspect', 'slope', 
               'tree_cover', 'nontree_cover',
                    'burn_depth', 'bg_c_combusted']
columns = ['post_NBR', 'post_NBR2', 'diff_NBR', 'diff_NBR2', 'FRP', 'JD',
       'BA_patch', 'duration', 'sand', 'silt', 'clay', 'Tmax_terra',
       'Tmax_anomaly', 'Tmin_terra', 'Tmin_anomaly', 'VPD_terra',
       'VPD_anomaly', 'solar_down_terra', 'solar_down_anomaly', 'pdsi',
       'pdsi_anomaly', 'cwd', 'cwd_anomaly', 'moisture_terra',
       'moisture_anomaly', 'duff_moisture', 'finefuel_moisture', 'FWI',
       'duff_moisture_anomaly', 'finefuel_moisture_anomaly', 'FWI_anomaly',
       'LST', 'LST_anomaly_std', 'LST_persistence', 'SOC', 'bog', 'fen',
       'elevation', 'aspect', 'slope', 'tree_cover', 'nontree_cover',
       'burn_depth', 'bg_c_combusted', 'pred_depth', 'pred_bgc', 'AGB',
       'ag_c_combusted', 'pred_agcc']

df = data[columns]
df = df.reset_index(drop=True)
X, y = df.loc[:, df.columns[:-2]], df[df.columns[-2]]
X
# Out:
#      post_NBR  post_NBR2  diff_NBR  diff_NBR2        FRP   JD      BA_patch  \
# 0     -0.3574     0.0170  -0.87260   -0.31570  17.245178  180  1.022062e+09
# 1     -0.2994     0.0407  -0.87790   -0.30450  34.913792  190  1.022062e+09
# 2     -0.4611    -0.0848  -0.67450   -0.32060  96.693123  184  1.219686e+09
# 3     -0.3597     0.0058  -0.92600   -0.34070  22.635136  193  1.054754e+09
# 4      0.0019     0.1676  -0.54780   -0.17335  12.672477  190  1.054754e+09
# ..        ...        ...       ...        ...        ...  ...           ...
# 891   -0.4762    -0.0828  -1.05180   -0.41315  37.700001  234  1.798731e+08
# 892   -0.3051     0.0154  -0.87515   -0.31280  16.600000  236  1.798731e+08
# 893   -0.2752     0.0146  -0.94595   -0.30205  16.600000  236  1.798731e+08
# 894   -0.4764    -0.0987  -1.08410   -0.43970  37.700001  234  1.798731e+08
# 895   -0.4610    -0.1307  -1.10470   -0.46900  37.700001  234  1.798731e+08
#
#      duration        sand        silt  ...  elevation      aspect      slope  \
# 0          18  571.666667  249.666667  ...        570  108.024091   4.225210
# 1          18  595.000000  253.666667  ...        608   92.605999   5.113978
# 2          41  487.000000  265.000000  ...        380   97.984144   3.378998
# 3          36  499.000000  271.666667  ...        489   43.177480   0.927410
# 4          36  407.000000  339.333333  ...        440   48.909921   1.854334
# ..        ...         ...         ...  ...        ...         ...        ...
# 891        21  274.000000  613.333333  ...        449  264.583883   6.527001
# 892        21  289.000000  608.000000  ...        376  299.772909   9.798939
# 893        21  289.000000  608.000000  ...        340  278.376305  19.256453
# 894        21  274.000000  613.333333  ...        450  241.158813  13.642695
# 895        21  281.666667  607.000000  ...        444  283.377896   5.713710
#
#      tree_cover  nontree_cover  burn_depth  bg_c_combusted  pred_depth  \
# 0            29             48         0.0             0.0    9.498026
# 1            21             53         0.0             0.0    8.467768
# 2            41             34         0.0             0.0   11.371709
# 3            45             34         0.7            53.4    5.448076
# 4            51             15         0.7            34.9    5.385658
# ..          ...            ...         ...             ...         ...
# 891          66             13        31.4          8020.4   26.950504
# 892          53             28        32.2         10209.4   26.192990
# 893          48             33        33.0          8513.9   22.497799
# 894          66             13        33.4          8629.3   26.330330
# 895          56             37        34.2          8874.7   25.986160
#
#         pred_bgc  AGB
# 0    3651.447910  136
# 1    3011.933091  137
# 2    3363.421106   89
# 3    2822.660645   43
# 4    1708.030364   37
# ..           ...  ...
# 891  6761.248721   36
# 892  7051.375654   73
# 893  5446.412729  112
# 894  6423.989153   50
# 895  6856.913584   33
#
# [896 rows x 47 columns]

# %%
fig, ax = plt.subplots(figsize=(30, 12))
corrMatrix = df.corr(method='pearson')
sns.heatmap(corrMatrix, annot=True, fmt='.02f', cmap='Spectral_r')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Model inputs

# %%
local_path = '/media/amin/STORAGE/STORAGE/OneDrive/PhD/Landsat_BA'
trials_depth = pickle.load(open(f'{local_path}/Siberia/PeatFire/BG_CC/data/trials_depth.pkl', 'rb'))
best_depth_hopt = trials_depth.argmin
best_depth_hopt.update({"objective": "reg:squarederror", 
          'tree_method':'hist',
          'device': 'cuda', 
          #  'updater': 'grow_gpu_hist',        # GPU-enabled updater
          'nthread': 1,
          'eval_metric':'rmse',
          # 'n_jobs': 18
              })
trials_bgc = pickle.load(open(f'{local_path}/Siberia/PeatFire/BG_CC/data/trials_bgc.pkl', 'rb'))
best_bgc_hopt = trials_bgc.argmin
best_bgc_hopt.update({"objective": "reg:squarederror", 
          'tree_method':'hist',
          'device': 'cuda', 
          #  'updater': 'grow_gpu_hist',        # GPU-enabled updater
          'nthread': 1,
          'eval_metric':'rmse',
          # 'n_jobs': 18
              })
trials = pickle.load(open(f'{local_path}/Siberia/PeatFire/BG_CC/data/trials_agcc.pkl', 'rb'))
best_agcc_hopt = trials.argmin
best_agcc_hopt.update({"objective": "reg:squarederror", 
          'tree_method':'hist',
          'device': 'cuda', 
          #  'updater': 'grow_gpu_hist',        # GPU-enabled updater
          'nthread': 1,
          'eval_metric':'rmse',
          # 'n_jobs': 18
              })
best_agcc_hopt
# Out:
# {'colsample_bytree': 0.6792652555522787,
#  'gamma': 4.146091751594208,
#  'learning_rate': 0.17544278207725614,
#  'max_depth': 8,
#  'min_child_weight': 2.0,
#  'reg_alpha': 8.98522379547516,
#  'reg_lambda': 4.0431350566457365,
#  'subsample': 0.5889031081843417,
#  'objective': 'reg:squarederror',
#  'tree_method': 'hist',
#  'device': 'cuda',
#  'nthread': 1,
#  'eval_metric': 'rmse'}

# %%
best_depth_hopt
# Out:
# {'colsample_bytree': 0.8583066583623611,
#  'gamma': 0.25202534307914415,
#  'learning_rate': 0.04654086605752556,
#  'max_depth': 13,
#  'min_child_weight': 5.0,
#  'reg_alpha': 1.6986609580956173,
#  'reg_lambda': 15.760638486284062,
#  'subsample': 0.6056058096420451,
#  'objective': 'reg:squarederror',
#  'tree_method': 'hist',
#  'device': 'cuda',
#  'nthread': 1,
#  'eval_metric': 'rmse'}

# %%
history_depth = {'n_boost': 145,
 'test-r2-mean': 0.4998602000000001,
 'test-rmse-mean': 3.8066002213620096,
 'test-mae-mean': 2.817806851363807,
 'features': ['diff_NBR2',
  'duration',
  'sand',
  'silt',
  'clay',
  'Tmax_terra',
  'Tmax_anomaly',
  'Tmin_terra',
  'Tmin_anomaly',
  'VPD_anomaly',
  'solar_down_terra',
  'solar_down_anomaly',
  'pdsi_anomaly',
  'cwd_anomaly',
  'moisture_terra',
  'moisture_anomaly',
  'duff_moisture',
  'finefuel_moisture',
  'FWI',
  'LST_anomaly_std',
  'bog',
  'fen',
  'elevation',
  'tree_cover',
  'nontree_cover']}

history_bgc = {'n_boost': 142,
 'test-r2-mean': 0.2401013,
 'test-rmse-mean': 1528.0977711658102,
 'test-mae-mean': 1116.0162292549048,
 'features': ['FWI_anomaly',
  'LST_anomaly_std',
  'SOC',
  'bog',
  'fen',
  'elevation',
  'tree_cover',
  'nontree_cover',
  'pred_depth']}

history_agcc = {'n_boost': 22,
 'test-r2-mean': 0.4300357,
 'test-rmse-mean': 298.0543166948076,
 'test-mae-mean': 196.8304342276029,
 'features': ['post_NBR',
  'diff_NBR',
  'post_NBR2',
  'JD',
  'Tmax_anomaly',
  'Tmin_anomaly',
  'VPD_terra',
  'VPD_anomaly',
  'solar_down_terra',
  'solar_down_anomaly',
  'cwd',
  'moisture_terra',
  'moisture_anomaly',
  'duff_moisture',
  'finefuel_moisture',
  'FWI_anomaly',
  'LST_anomaly_std',
  'SOC',
  'bog',
  'AGB']}

# %% [markdown]
# ## Models

# %%
np.random.seed(42)
X = df[history_depth['features']]
obs_depth = df['burn_depth']
model_depth = xgb.XGBRegressor(n_estimators=history_depth['n_boost'], random_state=42, **best_depth_hopt)
model_depth.fit(X, obs_depth)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8583066583623611, device='cuda',
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric='rmse', feature_types=None, gamma=0.25202534307914415,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.04654086605752556,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=13, max_leaves=None,
#              min_child_weight=5.0, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=145, n_jobs=None, nthread=1,
#              num_parallel_tree=None, ...)

# %%
plt.hist(model_depth.predict(X))
# Out:
# (array([ 36., 160., 238., 203., 137.,  61.,  27.,  22.,   4.,   8.]),
#  array([ 2.63324642,  5.19424343,  7.75524044, 10.31623745, 12.87723446,
#         15.43823242, 17.99922943, 20.56022644, 23.12122345, 25.68222046,
#         28.24321747]),
#  <BarContainer object of 10 artists>)

# %%
np.random.seed(42)
X = df[history_bgc['features']]
obs_bgc = df['bg_c_combusted']
model_bgc = xgb.XGBRegressor(n_estimators=history_bgc['n_boost'], random_state=42, **best_bgc_hopt)
model_bgc.fit(X, obs_bgc)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.5539977818438451, device='cuda',
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric='rmse', feature_types=None, gamma=1.7213866789715178,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01648833874441485,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=1.0, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=142, n_jobs=None, nthread=1,
#              num_parallel_tree=None, ...)

# %%
model_bgc.predict(X)
# Out:
# array([1982.2688, 1916.3823, 2147.1653, 1490.3752, 1065.0581, 1721.3544,
#        1506.2792, 2234.4062, 2623.22  , 1203.0997, 1937.4155, 1266.143 ,
#        1059.539 , 1875.1897, 1353.3812, 1778.5839, 2101.8218, 2405.9102,
#        1208.3412, 1657.8268, 2492.8813, 1862.6202, 1134.4929, 2987.5085,
#        1304.8876, 1954.9375, 2695.7195, 1763.6173, 2338.9243, 1098.1361,
#        2212.8174, 1881.8672, 1336.0706, 2261.542 , 1876.226 , 3020.6206,
#        1677.2136, 2489.8398, 2400.9868, 2737.1926, 1763.7362, 3600.4502,
#        1266.8414, 2945.1428, 1732.5757, 1834.4059, 1506.1714, 1902.1621,
#        2461.5608, 1860.3942, 1563.6913, 1395.8027, 1911.7864, 1559.196 ,
#        1739.8896, 2070.9072, 1230.2976, 2115.7722, 1249.1702, 2331.8745,
#        1625.9258, 1170.6923, 2304.516 , 1437.4712, 1911.5923, 2310.874 ,
#        2212.3071, 2112.3828, 3031.1008, 3583.7441, 1930.8619, 1826.6044,
#        1420.2712, 2092.799 , 2340.5786, 1923.4675, 2083.4072, 1330.6432,
#        1922.904 , 1896.4558, 1969.1947, 2644.028 , 2381.65  , 1946.6436,
#        2704.1523, 1730.4218, 2273.4675, 1812.3618, 2552.031 , 2103.3848,
#        2592.367 , 1949.4058, 1730.3817, 3202.9631, 2059.5537, 2067.8223,
#        1720.4658, 2895.255 , 2511.6633, 2145.9065, 1931.6711, 1793.8046,
#        3291.4739, 1522.0681, 1562.4569, 2015.3077, 2061.987 , 1942.7797,
#        1949.3806, 2033.3647, 1608.9915, 4091.7256, 2436.4001, 1756.4321,
#        1820.584 , 1456.2389, 2032.6785, 1543.6589, 3464.8254, 1968.8292,
#        1756.0813, 1839.861 , 2766.3552, 1657.9333, 1756.0002, 2495.994 ,
#        2475.4375, 4492.141 , 3007.0645, 1894.14  , 1643.0356, 2385.692 ,
#        2805.5732, 1807.1792, 2606.1223, 1786.3467, 1821.329 , 2792.8953,
#        1839.5043, 1883.2854, 1785.1716, 3565.606 , 1534.6553, 2134.802 ,
#        3013.9358, 3780.5962, 2551.1206, 1813.0853, 2509.3726, 1785.1716,
#        2217.9932, 2114.0122, 2789.2964, 1935.0476, 1871.3829, 2527.8403,
#        2030.2339, 3808.0068, 2006.365 , 2416.8584, 2000.421 , 1802.2559,
#        1977.2849, 1883.2854, 2785.1277, 2715.7678, 2452.5364, 1788.2771,
#        1925.6302, 3108.3518, 3047.7192, 2647.9656, 2962.803 , 3100.7043,
#        2405.6455, 2742.4998, 2007.7133, 2551.567 , 1767.0945, 4061.569 ,
#        2011.396 , 2877.5027, 4456.4775, 1353.1692, 2615.2388, 3055.197 ,
#        2650.3599, 1432.1323, 2490.166 , 2475.5535, 1785.5581, 1911.4777,
#        2666.9004, 1902.9176, 2041.4438, 3231.2327, 2222.0464, 3216.07  ,
#        2050.7295, 3207.7727, 1960.1256, 2282.2805, 2421.2278, 2717.605 ,
#        2586.8792, 2518.1768, 3325.289 , 1825.9387, 1778.5513, 2866.6074,
#        3185.8313, 2240.434 , 3082.319 , 2239.2993, 1900.5719, 1906.7966,
#        2651.111 , 3836.2388, 2051.7683, 3547.263 , 3341.7144, 2801.6594,
#        2152.4414, 2088.164 , 2919.5334, 2794.9714, 2895.5312, 2218.0137,
#        2402.0354, 2270.237 , 3081.0002, 2021.6722, 1963.7593, 1903.6416,
#        1885.9524, 2070.726 , 2734.054 , 1860.5231, 3142.433 , 3441.5164,
#        2926.0857, 2845.7856, 2036.3398, 2839.2527, 3577.7424, 2653.2805,
#        3236.8306, 2236.9243, 1936.4158, 2948.4678, 2803.095 , 1939.8617,
#        2017.0238, 2398.2334, 2912.9463, 2645.9224, 2358.8733, 3553.6807,
#        2766.1726, 2767.1033, 2532.511 , 2549.1292, 2451.3625, 3010.8535,
#        2151.7068, 3118.4475, 3029.2544, 2538.501 , 2437.9475, 3224.3892,
#        2511.0767, 2452.208 , 4092.8513, 2480.7363, 3064.683 , 2298.0215,
#        2979.948 , 3136.8093, 3092.634 , 2684.4863, 2329.9463, 3848.8872,
#        3263.0227, 3534.912 , 2163.7905, 2294.019 , 1987.7655, 2738.757 ,
#        2311.158 , 2858.5469, 3066.0261, 3007.6323, 3157.0662, 3049.364 ,
#        2859.0842, 1934.4283, 2275.2622, 2953.163 , 2809.3037, 3115.0225,
#        3143.9373, 2407.416 , 2883.8867, 3611.562 , 2682.9192, 3300.7917,
#        2697.215 , 2244.3452, 3324.5225, 2512.7202, 2560.236 , 3334.3958,
#        2245.358 , 2581.7646, 3306.9775, 3375.041 , 2814.4211, 3072.9673,
#        3811.3433, 3167.0215, 3517.0103, 2873.2693, 2724.7576, 3097.2683,
#        2462.0908, 2379.6538, 2933.287 , 3063.0261, 2832.0002, 4490.376 ,
#        2698.8064, 2036.7286, 2624.1528, 2308.5022, 2865.4001, 2620.2874,
#        2982.7917, 3018.6885, 2945.3618, 3111.453 , 2292.6875, 2051.059 ,
#        3282.6348, 2922.0051, 2737.7234, 3408.1953, 2565.5776, 2576.9277,
#        2920.9045, 2755.2153, 1857.4314, 2147.748 , 2819.444 , 2547.0999,
#        2874.5217, 2274.333 , 2538.0981, 2589.3196, 3763.2952, 3223.8298,
#        2861.1816, 2900.4844, 3437.1309, 3127.3796, 2302.773 , 2729.4985,
#        2794.7961, 2767.4788, 3696.1152, 2564.2615, 3077.986 , 3661.908 ,
#        2950.8735, 4626.111 , 3400.9746, 3563.9119, 3188.6904, 2813.8792,
#        2301.1702, 2480.4287, 2317.0115, 2480.3901, 2708.2222, 2975.4363,
#        2123.6567, 3114.9685, 2319.1504, 2632.1133, 2887.679 , 2400.5771,
#        3033.9878, 2289.1938, 4534.6855, 2904.3184, 2277.988 , 3271.6433,
#        3126.564 , 3324.135 , 2698.6978, 3142.9727, 2434.869 , 3647.0742,
#        2262.2295, 2394.8232, 2856.4731, 2945.5098, 2546.4897, 3228.0068,
#        2329.12  , 3574.115 , 2912.643 , 2939.417 , 3080.0989, 2867.422 ,
#        2859.0427, 2876.3784, 2567.657 , 2320.7063, 5639.3203, 2459.4614,
#        3662.2014, 3635.9607, 2442.7988, 2930.3008, 2594.258 , 2009.351 ,
#        2742.9885, 3300.9824, 2244.0278, 3474.6038, 2735.48  , 2189.3696,
#        3453.8022, 2847.9443, 3633.2656, 3429.3987, 2788.808 , 2650.0034,
#        2753.442 , 2955.8677, 2839.8855, 3378.1213, 3456.4026, 4457.1846,
#        4061.3743, 2879.003 , 2258.655 , 3454.805 , 2366.8523, 2315.0771,
#        3592.1885, 2666.2898, 2512.315 , 2883.9827, 3405.4001, 2412.5613,
#        3233.376 , 3030.9521, 3544.1306, 3298.4934, 2877.768 , 2202.9956,
#        3428.7515, 3970.3406, 2902.0955, 2332.055 , 2466.039 , 3976.0005,
#        3138.089 , 2982.1448, 2910.448 , 3222.4065, 2408.2222, 2519.9636,
#        2471.3079, 3238.2764, 2889.518 , 2740.632 , 3454.409 , 2832.4968,
#        4232.5215, 3258.1985, 2908.4697, 2670.5269, 6065.038 , 2196.04  ,
#        3278.1514, 3100.1187, 3002.2712, 3480.2737, 3658.5686, 3090.4531,
#        3034.377 , 2257.0269, 2237.7231, 3013.0852, 2477.9404, 2354.2034,
#        3676.2063, 3490.7783, 3117.329 , 2400.54  , 3272.8652, 2582.3555,
#        2942.245 , 3613.854 , 2999.3223, 2992.3577, 3326.992 , 3333.9233,
#        3036.5417, 2173.7944, 2304.358 , 3019.7288, 2362.022 , 3521.4502,
#        2829.13  , 2923.5845, 4269.46  , 3318.839 , 2393.7996, 3093.007 ,
#        2736.7302, 2299.181 , 4135.1455, 3323.1077, 3141.5703, 2941.7144,
#        3218.271 , 3566.6143, 3127.4326, 2510.8774, 2031.8846, 3821.6172,
#        2373.1724, 2297.0034, 2599.8613, 3101.2678, 2855.3337, 3076.6028,
#        3336.334 , 2864.9565, 2832.1052, 3863.9387, 4533.4146, 3551.438 ,
#        4065.1187, 3262.0542, 2506.1833, 2981.69  , 2650.2776, 2460.022 ,
#        3080.7605, 3334.592 , 3034.1443, 3456.5242, 3659.1135, 3566.7358,
#        2408.772 , 3117.1223, 2336.2708, 3640.069 , 3060.3386, 3861.9844,
#        2933.5405, 2261.2432, 4690.2954, 2424.392 , 2880.95  , 1866.8833,
#        3970.6445, 2769.36  , 3017.7876, 2955.1575, 2315.5867, 3491.2551,
#        3186.685 , 3881.3618, 2377.4937, 2653.695 , 3435.6704, 2463.1287,
#        4138.8594, 2602.1257, 4829.191 , 3364.9348, 3346.8232, 3194.474 ,
#        2364.4531, 4519.4536, 2152.2524, 3202.6282, 2367.9026, 3684.4607,
#        3400.9133, 3498.1465, 4144.261 , 3369.0017, 3028.113 , 3683.9082,
#        2738.938 , 2890.0989, 3107.406 , 2407.65  , 2519.8735, 2491.9043,
#        3767.952 , 3048.792 , 3621.1724, 3205.6182, 3778.4177, 3220.0498,
#        3249.0876, 3215.997 , 2944.5498, 3159.5603, 4413.3657, 2440.4705,
#        3195.0735, 2185.2024, 3156.9   , 3314.7568, 4067.9595, 2566.8484,
#        3866.5598, 3321.779 , 4023.5474, 3591.5767, 2547.9778, 3906.895 ,
#        3733.6768, 3242.9956, 3628.1633, 3082.5613, 2307.997 , 3456.2222,
#        4177.3926, 3096.5283, 5026.902 , 2483.9563, 2203.9556, 4444.3335,
#        2112.7612, 4410.218 , 3619.3535, 4981.4556, 3811.8916, 2965.062 ,
#        2967.0264, 3232.6328, 3544.017 , 3507.2898, 3706.969 , 4005.237 ,
#        2881.9683, 3972.537 , 3300.6692, 5769.1553, 2971.6455, 3722.0642,
#        3295.5408, 4092.048 , 4312.7764, 2999.8076, 2464.7488, 3773.7803,
#        3553.1978, 3669.8982, 2928.4568, 2776.768 , 3787.603 , 3448.0825,
#        2745.3254, 4302.162 , 3557.8745, 3718.166 , 3511.0095, 4381.072 ,
#        3386.399 , 3831.364 , 3772.542 , 2462.0012, 2838.01  , 3025.3904,
#        4298.089 , 2880.3772, 4050.0942, 3910.3838, 2998.8179, 3195.9392,
#        4147.699 , 3294.2832, 2237.3018, 3874.4058, 3755.3765, 2811.3074,
#        3869.7126, 3853.1414, 3935.8777, 2970.2722, 3616.9985, 5741.7236,
#        4474.1787, 3285.2146, 3113.47  , 3690.0369, 4009.4387, 3564.5627,
#        3834.1104, 2977.6545, 3601.9644, 3060.7295, 2561.7534, 4582.619 ,
#        2963.2063, 2765.905 , 3115.3179, 3455.9204, 4671.363 , 3268.8003,
#        3972.1133, 2745.3477, 3528.1191, 5792.2285, 2722.453 , 3086.5598,
#        4047.7178, 3088.9482, 6376.164 , 3499.7134, 3050.3354, 3860.824 ,
#        2863.3955, 2885.774 , 3333.1326, 3745.5703, 2710.459 , 3722.6511,
#        2970.7869, 3669.025 , 3567.8784, 4131.7744, 4290.674 , 2945.8835,
#        3101.2444, 2996.4043, 4058.5527, 1954.4799, 4880.1562, 3414.1606,
#        3427.4543, 4223.2603, 4223.2603, 4766.7627, 3842.5151, 3110.1948,
#        3955.955 , 4042.264 , 3160.5085, 3896.062 , 3562.8914, 4550.447 ,
#        4044.7383, 2266.8018, 2977.5454, 3487.305 , 3235.6743, 3920.7563,
#        4385.923 , 4782.093 , 3308.2258, 4211.439 , 1952.16  , 3704.6353,
#        4551.1245, 3977.8535, 3145.038 , 4827.38  , 2480.6777, 3512.0405,
#        3172.4954, 3435.2837, 2029.1809, 2175.3936, 3170.4788, 2586.081 ,
#        4505.417 , 3882.6274, 3503.6523, 5054.978 , 4100.631 , 4359.802 ,
#        4035.2449, 4121.6133, 3636.4734, 3733.8972, 3808.3901, 4485.5034,
#        3257.9478, 3357.5293, 2504.7656, 3240.2634, 3733.906 , 4466.3164,
#        3394.6948, 4513.0425, 3529.855 , 2306.9365, 3185.0803, 3761.2515,
#        3302.0762, 1976.0461, 3934.4053, 4552.261 , 4732.625 , 4676.464 ,
#        3863.1506, 2788.5488, 3939.516 , 5248.636 , 3028.4915, 3396.4546,
#        4340.2603, 4178.2153, 4627.1   , 4019.2017, 3615.0015, 4168.1777,
#        4814.053 , 2941.274 , 5855.236 , 4545.563 , 4616.853 , 3689.3223,
#        4266.4785, 1959.3085, 3556.058 , 4509.324 , 4892.373 , 3888.857 ,
#        4056.2607, 4461.358 , 2377.3206, 2579.2302, 4349.6816, 4196.334 ,
#        3097.6692, 4679.7876, 4561.404 , 4353.101 , 3920.3267, 5457.0933,
#        4406.5757, 4745.9185, 5336.6494, 5632.693 , 4293.589 , 3914.5603,
#        5684.762 , 3576.6072, 5089.642 , 2599.1301, 5729.8496, 4183.2344,
#        7186.732 , 2467.124 , 4955.1895, 4497.286 , 4479.4688, 5256.879 ,
#        5782.0586, 2776.5913, 2212.3992, 4704.911 , 4639.3613, 6637.878 ,
#        5707.8413, 3843.1245, 5836.241 , 6359.5244, 4469.9263, 5101.332 ,
#        5081.432 , 5835.5156, 5179.7393, 4974.7666, 5287.699 , 5350.372 ,
#        7340.92  , 7071.177 , 6649.2007, 7005.624 , 7579.754 , 6929.6543,
#        7074.0166, 7527.69  ], dtype=float32)

# %%
plt.hist(model_bgc.predict(X))
# Out:
# (array([ 36., 186., 259., 219., 105.,  52.,  14.,  13.,   4.,   8.]),
#  array([1059.53894043, 1711.5604248 , 2363.58203125, 3015.60351562,
#         3667.625     , 4319.64648438, 4971.66796875, 5623.68945312,
#         6275.7109375 , 6927.73242188, 7579.75390625]),
#  <BarContainer object of 10 artists>)

# %%
np.random.seed(42)
df2 = df.copy().query('ag_c_combusted >= 0 & ag_c_combusted < 5000').drop(columns=['bg_c_combusted', 'burn_depth'])
X = df2[history_agcc['features']]
obs_agcc = df2['ag_c_combusted']
obs_agcc
# Out:
# 0      1719.306
# 1      2252.180
# 2      1293.367
# 3       794.981
# 4       234.666
#          ...
# 878      16.589
# 879     221.455
# 883    1950.053
# 886     600.436
# 887      37.188
# Name: ag_c_combusted, Length: 586, dtype: float64

# %%
np.random.seed(42)
model_agcc = xgb.XGBRegressor(n_estimators=history_agcc['n_boost'], random_state=42, **best_agcc_hopt)
model_agcc.fit(X, obs_agcc)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6792652555522787, device='cuda',
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric='rmse', feature_types=None, gamma=4.146091751594208,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.17544278207725614,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=2.0, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=22, n_jobs=None, nthread=1,
#              num_parallel_tree=None, ...)

# %% [markdown]
# ## Predictor collection

# %%
local_path = '/media/amin/DISK6T/PhD/Landsat_BA/Siberia'

def get_peat_content(tile, local_path):
    names = [
             # 'Histel_fraction', 
             'Histel_SOC_hg_per_sqm', 'Histosol_SOC_hg_per_sqm', 
             'Histel_ombrotrophic', 'Histosol_ombrotrophic', 
             'Histel_minerotrophic', 'Histosol_minerotrophic'
            ]
    cols = [
            # 'permafrost', 
            'permafrost_SOC', 'nonpermafrost_SOC', 
            'permafrost_bog','nonpermafrost_bog', 
            'permafrost_fen','nonpermafrost_fen'
           ]
    ls_bog = []
    ls_fen = []
    ls_SOC = []
    for n, c in zip(names, cols):
        pathname = f'{local_path}/PeatFire/BG_CC/data/Higelius_Peat_properties/{n}_WGS84.nc'
        # print(pathname, n)
        filehandle = netCDF4.Dataset(pathname,'r',format="NETCDF4")
        values = filehandle.variables[f'{n}_WGS84.tif'][:]
        values.mask = False
        values[values==values.fill_value] = 0
        if 'bog' in c:
            # print(f'bog: {c}, {n}')
            ls_bog.append(values)
        elif 'fen' in c:
            # print(f'fen: {c}, {n}')
            ls_fen.append(values)
        elif 'SOC' in c:
            # print(f'SOC: {c}, {n}')
            ls_SOC.append(values)
        else:
            print(f'permafrost: {c}, {n}')
            permafrost = values.copy()
            
    lathandle = filehandle.variables['lat'][:]
    lonhandle = filehandle.variables['lon'][:]
    lats = np.round(lathandle[:], 2)
    lons = np.round(lonhandle[:], 2)
    xres = np.round(lons[1] - lons[0], 5)
    yres = np.round(lats[1] - lats[0], 5)
    xmin, ymin, xmax, ymax = int(tile[8:11]), int(tile[5:7])-2, int(tile[8:11])+3, int(tile[5:7])
    try:
        index_lon = slice(np.argwhere(lons==xmin+(xres/2))[0, 0], np.argwhere(lons==xmax+(xres/2))[0, 0])
    except:
        if xmax == 180:
            index_lon = slice(np.argwhere(lons==xmin+(xres/2))[0, 0], None)
    index_lat = slice(np.argwhere(lats==ymax+(yres/2))[0, 0], np.argwhere(lats==ymin+(yres/2))[0, 0])
    SOC = np.sum(ls_SOC, axis=0)[index_lat, index_lon]
    fen = np.sum(ls_fen, axis=0)[index_lat, index_lon]
    bog = np.sum(ls_bog, axis=0)[index_lat, index_lon]

    return {"SOC": SOC, 'bog': bog, 'fen': fen}

# %%
tile = 'TILE-64N177E'
peat = get_peat_content(tile, local_path)
plt.imshow(peat['SOC'], vmin=0, vmax=734)
plt.colorbar()

# %%
X.columns
# Out:
# Index(['post_NBR', 'post_NBR2', 'diff_NBR', 'diff_NBR2', 'FRP', 'JD',
#        'BA_patch', 'duration', 'sand', 'silt', 'clay', 'Tmax_terra',
#        'Tmax_anomaly', 'Tmin_terra', 'Tmin_anomaly', 'VPD_terra',
#        'VPD_anomaly', 'solar_down_terra', 'solar_down_anomaly', 'pdsi',
#        'pdsi_anomaly', 'cwd', 'cwd_anomaly', 'moisture_terra',
#        'moisture_anomaly', 'duff_moisture', 'finefuel_moisture', 'FWI',
#        'duff_moisture_anomaly', 'finefuel_moisture_anomaly', 'FWI_anomaly',
#        'LST', 'LST_anomaly_std', 'LST_persistence', 'SOC', 'bog', 'fen',
#        'elevation', 'aspect', 'slope', 'tree_cover', 'nontree_cover',
#        'burn_depth', 'bg_c_combusted'],
#       dtype='object')

# %%
peat_content = get_peat_content(tile, local_path)

# %%
climate_layers = dict(TerraClimate_Means={'bands': ['Tmax_terra', 'Tmin_terra', 'VPD_terra', 
                                            'solar_down_terra', 'pdsi', 'cwd', 'moisture_terra'],
                                 'scales': [0.1, 0.1, 0.01, 0.1, 0.01, 0.1, 0.1]},
             TerraClimate_Anomalies={'bands': ['Tmax_anomaly', 'Tmin_anomaly', 'VPD_anomaly', 
                                       'solar_down_anomaly',  'pdsi_anomaly', 'cwd_anomaly','moisture_anomaly']},
             ECMWF_CEMS_Means={'bands': ['duff_moisture', 'finefuel_moisture', 'FWI']},
             ECMWF_CEMS_Anomalies={'bands': ['duff_moisture_anomaly', 'finefuel_moisture_anomaly', 'FWI_anomaly']},
                     )
tiled_layers = dict(MOD44B_VCF={'bands': ['tree_cover', 'nontree_cover']},
             ALOSDEM30={'bands': ['elevation', 'aspect', 'slope']},
             NBR={'bands': ['post_NBR', 'post_NBR2', 'diff_NBR', 'diff_NBR2'],
                 'scales': [-1e-4, -1e-4, -1e-4, -1e-4]},
             LST_Mean={'bands': ['LST'], 'scales': [0.02]}, 
             LST_std_anomaly={'bands': ['LST_anomaly_std']}, 
             LST_persistence={'bands': ['LST_persistence']},
             SoilGrids_sand={'bands': ['sand']},
             SoilGrids_silt={'bands': ['silt']},
             SoilGrids_clay={'bands': ['clay']},
             AGB2010={'bands': ['AGB']}
                       )

# %%
X.columns
# Out:
# Index(['post_NBR', 'post_NBR2', 'diff_NBR', 'diff_NBR2', 'FRP', 'JD',
#        'BA_patch', 'duration', 'sand', 'silt', 'clay', 'Tmax_terra',
#        'Tmax_anomaly', 'Tmin_terra', 'Tmin_anomaly', 'VPD_terra',
#        'VPD_anomaly', 'solar_down_terra', 'solar_down_anomaly', 'pdsi',
#        'pdsi_anomaly', 'cwd', 'cwd_anomaly', 'moisture_terra',
#        'moisture_anomaly', 'duff_moisture', 'finefuel_moisture', 'FWI',
#        'duff_moisture_anomaly', 'finefuel_moisture_anomaly', 'FWI_anomaly',
#        'LST', 'LST_anomaly_std', 'LST_persistence', 'SOC', 'bog', 'fen',
#        'elevation', 'aspect', 'slope', 'tree_cover', 'nontree_cover',
#        'burn_depth', 'bg_c_combusted'],
#       dtype='object')

# %%
def get_climate(tile, year, local_path):
    climate_layers = dict(TerraClimate_Means={'bands': ['Tmax_terra', 'Tmin_terra', 'VPD_terra', 
                                                'solar_down_terra', 'pdsi', 'cwd', 'moisture_terra'],
                                     'scales': [0.1, 0.1, 0.01, 0.1, 0.01, 0.1, 0.1]},
                 TerraClimate_Anomalies={'bands': ['Tmax_anomaly', 'Tmin_anomaly', 'VPD_anomaly', 
                                           'solar_down_anomaly',  'pdsi_anomaly', 'cwd_anomaly','moisture_anomaly']},
                 ECMWF_CEMS_Means={'bands': ['duff_moisture', 'finefuel_moisture', 'FWI']},
                 ECMWF_CEMS_Anomalies={'bands': ['duff_moisture_anomaly', 'finefuel_moisture_anomaly', 'FWI_anomaly']},
                         )
    climate = {}
    for l in tuple(climate_layers.keys())[:]:
        # print(l)
        ds = gdal.Open(f'{local_path}/PeatFire/BG_CC/data/{l}/{l}_Siberia_{year}.tif')
        gt = ds.GetGeoTransform()
        xmin, ymin, xmax, ymax = int(tile[8:11]), int(tile[5:7])-2, int(tile[8:11])+3, int(tile[5:7])
        index_lat = slice(int((ymax - gt[3])/gt[5]), int((ymin - gt[3])/gt[5]))
        index_lon = slice(int((xmin - gt[0])/gt[1]), int((xmax - gt[0])/gt[1]))
        for i, band in enumerate(climate_layers[l]['bands']):
            climate[band] = ds.GetRasterBand(i+1).ReadAsArray()
            if 'scales' in climate_layers[l].keys():
                # print(band, climate_layers[l]['scales'][i], climate[band].shape)
                climate[band] = climate[band] * climate_layers[l]['scales'][i]
            climate[band] = climate[band][index_lat, index_lon]
        
    return climate

# %%
climate['FWI'].shape
# Out:
# (8, 12)

# %%
tile = 'TILE-64N126E'
climate = get_climate(tile, 2001, local_path)
plt.imshow(climate['Tmin_terra'])
plt.colorbar()

# %%
1/24
# Out:
# 0.041666666666666664

# %% [markdown]
# ## Run predictions

# %%
def predict_model(tile, year, local_path, model_depth=None, history_depth=None, 
      model_bgc=None, history_bgc=None, model_agcc=None, history_agcc=None, agg_res=0.25, logfile=False):
# year = 2021
# tile = 'TILE-60N069E'
# agg_res = 0.25
# logfile=False
    if not logfile:
        logfile = io.StringIO()

    os.makedirs(f'{local_path}/PeatFire/ByTile/{tile}/Results', exist_ok=True)
    predictors = {}
    # used_features = history_depth['features'] + history_bgc['features'] + history_agcc['features']
    used_features = history_agcc['features']
    climate_layers = dict(TerraClimate_Means={'bands': ['Tmax_terra', 'Tmin_terra', 'VPD_terra', 
                                            'solar_down_terra', 'pdsi', 'cwd', 'moisture_terra'],
                                 'scales': [0.1, 0.1, 0.01, 0.1, 0.01, 0.1, 0.1]},
             TerraClimate_Anomalies={'bands': ['Tmax_anomaly', 'Tmin_anomaly', 'VPD_anomaly', 
                                       'solar_down_anomaly',  'pdsi_anomaly', 'cwd_anomaly','moisture_anomaly']},
             ECMWF_CEMS_Means={'bands': ['duff_moisture', 'finefuel_moisture', 'FWI']},
             ECMWF_CEMS_Anomalies={'bands': ['duff_moisture_anomaly', 'finefuel_moisture_anomaly', 'FWI_anomaly']},
                     )
    tiled_layers = dict(MOD44B_VCF={'bands': ['tree_cover', 'nontree_cover']},
             ALOSDEM30={'bands': ['elevation', 'aspect', 'slope']},
             NBR={'bands': ['post_NBR', 'post_NBR2', 'diff_NBR', 'diff_NBR2'],
                 'scales': [-1e-4, -1e-4, -1e-4, -1e-4]},
             LST_Mean={'bands': ['LST'], 'scales': [0.02]}, 
             LST_std_anomaly={'bands': ['LST_anomaly_std']}, 
             LST_persistence={'bands': ['LST_persistence']},
             SoilGrids_sand={'bands': ['sand']},
             SoilGrids_silt={'bands': ['silt']},
             SoilGrids_clay={'bands': ['clay']},
             AGB2010={'bands': ['AGB']}
                       )
    BA_file = f'{local_path}/ByTile/{tile}/Enhanced/Yearly/BAMT_BA_Siberia_Lndst_{year}_{tile}_JD_Correct_Patches.tif'
    ds = gdal.Open(BA_file)
    JD = ds.GetRasterBand(1).ReadAsArray()
    mask_BA = JD > 0
    res = str(agg_res).replace(".", "")
    grid_ref = f'{local_path}/PeatFire/ByTile/{tile}/Grid/BA_Area_{res}D_{tile}_{year}.tif'
    n_BA = np.count_nonzero(mask_BA)
    Global_Functions.print_and_log(logfile, f'\n\t\t{15 * "-"} {tile}: {n_BA} pixels burned {15 * "-"}')  
    if n_BA > 0:
        ds = gdal.Open(f'{local_path}/PeatFire/ByTile/{tile}/Pixel/BA_Peatland_{tile}_{year}.tif')
        peatfire = ds.GetRasterBand(1).ReadAsArray()
        mask_peatfires = peatfire > 0        
        if 'JD' in used_features:
            predictors['JD'] = JD[mask_BA]
        if 'FRP' in used_features:
            ds = gdal.Open(f'{local_path}/ByTile/{tile}/Voronoi/FRP/Hotspots_FRP_{year}_{tile}.tif')
            predictors['FRP'] = ds.GetRasterBand(1).ReadAsArray()[mask_BA]
        
        if np.isin(['duration', 'BA_patch'], used_features).any(): 
            ds = gdal.Open(f"{local_path}/ByTile/{tile}/Patches/TIF/BAMT_BA_Siberia_Lndst_Patches-16_{year}_{tile}.tif")
            labels = ds.GetRasterBand(1).ReadAsArray()
            lookup = pd.read_csv(f"{local_path}/ByTile/{tile}/Patches/Tabular/BAMT_BA_Siberia_Lndst_Patch-Stats-16_{year}_{tile}.csv")
            lookup['id'] = lookup['ID'].apply(lambda x: int(x.split('_')[-1]))
            if 'duration' in used_features:
                predictors['duration'] = Global_Functions.replace_numpy_list(labels[mask_BA], lookup['id'].values, 
                                                             lookup['DURATION'].values)
            else:
                predictors['BA_patch'] = Global_Functions.replace_numpy_list(labels[mask_BA], lookup['id'].values, 
                                                             lookup['AREA'].values)
        
        for l, c in tiled_layers.items():
                if os.path.isfile(f'{local_path}/PeatFire/ByTile/{tile}/Predictors/{l}_Siberia_{year}_{tile}.tif'):
                    ds = gdal.Open(f'{local_path}/PeatFire/ByTile/{tile}/Predictors/{l}_Siberia_{year}_{tile}.tif')
                elif l not in ['ALOSDEM30', 'AGB2010'] and 'SoilGrids' not in l:
                    print(f'{l} is not available for {year}, replaced by 2020')   ### VCF tree/non-tree cover
                    ds = gdal.Open(f'{local_path}/PeatFire/ByTile/{tile}/Predictors/{l}_Siberia_2020_{tile}.tif')
                else:
                    ds = gdal.Open(f'{local_path}/PeatFire/ByTile/{tile}/Predictors/{l}_Siberia_{tile}.tif')
                    
                for i, band in enumerate(tiled_layers[l]['bands']):
                    if band in used_features:
                        predictors[band] = ds.GetRasterBand(i+1).ReadAsArray()[mask_BA]
                        if 'scales' in tiled_layers[l].keys():
                            # print(band, tiled_layers[l]['scales'][i])
                            predictors[band] = predictors[band] * tiled_layers[l]['scales'][i]
                    # else:
                    #     print(f'{band} is not included in the model')
        peat_content = get_peat_content(tile, local_path)
        for l in peat_content.keys():
            if l in used_features:
                scale = 8000 // peat_content[l].shape[0]
                predictors[l] = np.repeat(np.repeat(peat_content[l], scale, 0), scale, 1)[mask_BA]
        climate = get_climate(tile, year, local_path)
        for l in climate.keys():
            if l in used_features:
                ## a maximum of 1/3 of the pixel is shifted towards the end
                scale = round(8000 / climate[l].shape[0])
                predictors[l] = np.repeat(np.repeat(climate[l], scale, 0), scale, 1)[:8000, :12000][mask_BA]
                
        # predictors = dict(sorted(predictors.items(), key=lambda item: history_depth['features'].index(item[0])))
        dmatrix = pd.DataFrame(data=np.column_stack([predictors[key] for key in history_depth['features']]), 
                                  columns=history_depth['features']).astype(np.float32)
        # dmatrix = xgb.DMatrix(data=np.column_stack([predictors[key] for key in history_depth['features']]), 
        #                           feature_names=history_depth['features'])
        if n_BA < 1e7:
            pred_depth = model_depth.predict(dmatrix)
        else:
            Global_Functions.print_and_log(logfile, f'\n *** {n_BA} pixels burned: Use DASK {15 * "-"}')  
            cluster = LocalCluster(n_workers=1, threads_per_worker=1)
            client = Client(cluster)    
            dmatrix = dd.from_pandas(dmatrix, npartitions=int(np.ceil(n_BA / 1e7)))
            pred_depth = dxgb.predict(client, model_depth.get_booster(), dmatrix)
        del dmatrix
        predictors['pred_depth'] = pred_depth
        dmatrix = pd.DataFrame(data=np.column_stack([predictors[key] for key in history_bgc['features']]), 
                                  columns=history_bgc['features']).astype(np.float32)
        # dmatrix = xgb.DMatrix(data=np.column_stack([predictors[key] for key in history_bgc['features']]), 
        #                           feature_names=history_bgc['features'])
        if n_BA < 1e7:
            pred_bgc = model_bgc.predict(dmatrix)
        else: 
            dmatrix = dd.from_pandas(dmatrix, npartitions=int(np.ceil(n_BA / 1e7)))
            pred_bgc = dxgb.predict(client, model_bgc.get_booster(), dmatrix)
            # client.close()
            # cluster.close()
        del dmatrix

        reshaped_depth = np.full(mask_BA.shape, -9999, np.float32)
        reshaped_bgc = np.full(mask_BA.shape, -9999, np.float32)
        reshaped_depth[mask_BA] = pred_depth
        reshaped_bgc[mask_BA] = pred_bgc
        area = Global_Functions.get_pixel_area(BA_file, area_1d=True)
        creation_dict = {'ALL': mask_BA, 
                        'PEAT': mask_peatfires}
        for layer, mask in creation_dict.items():
            if layer == 'PEAT':
                reshaped_depth[~mask] = -9999
                reshaped_bgc[~mask] = -9999
            reshaped_depth = np.ma.masked_where(~mask, reshaped_depth)
            reshaped_bgc = np.ma.masked_where(~mask, reshaped_bgc)
            np.ma.set_fill_value(reshaped_depth, -9999)
            np.ma.set_fill_value(reshaped_bgc, -9999)
            scale = int(agg_res / 0.00025)
            agg_bgc = np.nanmean(reshaped_bgc.reshape(reshaped_bgc.shape[0] // scale, scale, 
                                    reshaped_bgc.shape[1] // scale, scale), axis=(1, 3)) 
            agg_depth = np.nanmean(reshaped_depth.reshape(reshaped_depth.shape[0] // scale, scale, 
                                    reshaped_depth.shape[1] // scale, scale), axis=(1, 3)) 
            np.ma.set_fill_value(agg_bgc, -9999)
            np.ma.set_fill_value(agg_depth, -9999)
            area_bgc = (reshaped_bgc.transpose() * area).transpose() * 1e-6  ## from g to T
            agg_bgc_sum = np.nansum(area_bgc.reshape(area_bgc.shape[0] // scale, scale, 
                                    area_bgc.shape[1] // scale, scale), axis=(1, 3)) 
            # print(layer, agg_bgc_sum[agg_bgc_sum > 0])
            
            Global_Functions.write_rasterio(reshaped_depth, f'{local_path}/PeatFire/ByTile/{tile}/Results/BurnDepth_{layer}_{year}_{tile}.tif',
                                           BA_file, nodata=-9999, custom_dtype=True, dtype='float32')
            Global_Functions.write_rasterio(reshaped_bgc, f'{local_path}/PeatFire/ByTile/{tile}/Results/BGCC-gCm2_{layer}_{year}_{tile}.tif',
                                           BA_file, nodata=-9999, custom_dtype=True, dtype='float32')
            Global_Functions.write_rasterio(agg_bgc_sum, nodata=-9999, refPath=grid_ref, 
                    OutPath=f'{local_path}/PeatFire/ByTile/{tile}/Results/BGCC-MgC_SUM_{res}D_{layer}_{year}_{tile}.tif')
            Global_Functions.write_rasterio(agg_bgc, nodata=-9999, refPath=grid_ref, 
                    OutPath=f'{local_path}/PeatFire/ByTile/{tile}/Results/BGCC-gCm2_Burned_{res}D_{layer}_{year}_{tile}.tif')
            Global_Functions.write_rasterio(agg_depth, nodata=-9999, refPath=grid_ref, 
                    OutPath=f'{local_path}/PeatFire/ByTile/{tile}/Results/BurnDepth_MEAN_{res}D_{layer}_{year}_{tile}.tif')
        
    
        dmatrix = pd.DataFrame(data=np.column_stack([predictors[key] for key in history_agcc['features']]), 
                                  columns=history_agcc['features']).astype(np.float32)
        if n_BA < 1e7:
            pred_agcc = model_agcc.predict(dmatrix)
        else:
            Global_Functions.print_and_log(logfile, f'\n *** {n_BA} pixels burned: Use DASK {15 * "-"}')  
            cluster = LocalCluster(n_workers=1, threads_per_worker=1)
            client = Client(cluster)    
            dmatrix = dd.from_pandas(dmatrix, npartitions=int(np.ceil(n_BA / 1e7)))
            pred_agcc = dxgb.predict(client, model_agcc.get_booster(), dmatrix)
        del dmatrix
        # client.close()
        # cluster.close()

        reshaped_agcc = np.full(mask_BA.shape, -9999, np.float32)
        reshaped_agcc[mask_BA] = pred_agcc
        area = Global_Functions.get_pixel_area(BA_file, area_1d=True)
        creation_dict = {'ALL': mask_BA, 
                        'PEAT': mask_peatfires}
        for layer, mask in creation_dict.items():
            if layer == 'PEAT':
                reshaped_agcc[~mask] = -9999
            reshaped_agcc = np.ma.masked_where(~mask, reshaped_agcc)
            np.ma.set_fill_value(reshaped_agcc, -9999)
            scale = int(agg_res / 0.00025)
            agg_agcc = np.nanmean(reshaped_agcc.reshape(reshaped_agcc.shape[0] // scale, scale, 
                                    reshaped_agcc.shape[1] // scale, scale), axis=(1, 3)) 
            np.ma.set_fill_value(agg_agcc, -9999)
            area_agcc = (reshaped_agcc.transpose() * area).transpose() * 1e-6  ## from g to T
            agg_agcc_sum = np.nansum(area_agcc.reshape(area_agcc.shape[0] // scale, scale, 
                                    area_agcc.shape[1] // scale, scale), axis=(1, 3)) 

            Global_Functions.write_rasterio(reshaped_agcc, f'{local_path}/PeatFire/ByTile/{tile}/Results/AGCC-gCm2_{layer}_{year}_{tile}.tif',
                                           BA_file, nodata=-9999, custom_dtype=True, dtype='float32')
            Global_Functions.write_rasterio(agg_agcc_sum, nodata=-9999, refPath=grid_ref, 
                    OutPath=f'{local_path}/PeatFire/ByTile/{tile}/Results/AGCC-MgC_SUM_{res}D_{layer}_{year}_{tile}.tif')
            Global_Functions.write_rasterio(agg_agcc, nodata=-9999, refPath=grid_ref, 
                    OutPath=f'{local_path}/PeatFire/ByTile/{tile}/Results/AGCC-gCm2_Burned_MEAN_{res}D_{layer}_{year}_{tile}.tif')
    else:
        reshaped_depth = reshaped_bgc = reshaped_agcc = np.full(mask_BA.shape, -9999, np.float32)
        ds = gdal.Open(grid_ref)
        agg_depth = agg_bgc_sum = agg_bgc = agg_agcc_sum = agg_agcc = np.full((ds.RasterYSize, ds.RasterXSize), -9999, np.float32)
        creation_dict = {'ALL': [], 
                        'PEAT': []}
        for layer, mask in creation_dict.items():
            Global_Functions.write_rasterio(reshaped_depth, f'{local_path}/PeatFire/ByTile/{tile}/Results/BurnDepth_{layer}_{year}_{tile}.tif',
                                           BA_file, nodata=-9999, custom_dtype=True, dtype='float32')
            Global_Functions.write_rasterio(reshaped_bgc, f'{local_path}/PeatFire/ByTile/{tile}/Results/BGCC-gCm2_{layer}_{year}_{tile}.tif',
                                           BA_file, nodata=-9999, custom_dtype=True, dtype='float32')
            Global_Functions.write_rasterio(agg_bgc_sum, nodata=-9999, refPath=grid_ref, 
                    OutPath=f'{local_path}/PeatFire/ByTile/{tile}/Results/BGCC-MgC_SUM_{res}D_{layer}_{year}_{tile}.tif')
            Global_Functions.write_rasterio(agg_bgc, nodata=-9999, refPath=grid_ref, 
                    OutPath=f'{local_path}/PeatFire/ByTile/{tile}/Results/BGCC-gCm2_Burned_MEAN_{res}D_{layer}_{year}_{tile}.tif')
            Global_Functions.write_rasterio(agg_depth, nodata=-9999, refPath=grid_ref, 
                    OutPath=f'{local_path}/PeatFire/ByTile/{tile}/Results/BurnDepth_MEAN_{res}D_{layer}_{year}_{tile}.tif')
            Global_Functions.write_rasterio(reshaped_agcc, f'{local_path}/PeatFire/ByTile/{tile}/Results/AGCC-gCm2_{layer}_{year}_{tile}.tif',
                                           BA_file, nodata=-9999, custom_dtype=True, dtype='float32')
            Global_Functions.write_rasterio(agg_agcc_sum, nodata=-9999, refPath=grid_ref, 
                    OutPath=f'{local_path}/PeatFire/ByTile/{tile}/Results/AGCC-MgC_SUM_{res}D_{layer}_{year}_{tile}.tif')
            Global_Functions.write_rasterio(agg_agcc, nodata=-9999, refPath=grid_ref, 
                    OutPath=f'{local_path}/PeatFire/ByTile/{tile}/Results/AGCC-gCm2_Burned_MEAN_{res}D_{layer}_{year}_{tile}.tif')

    Global_Functions.print_and_log(logfile, f'\t\t+++++ Files are saved +++++\n')

    return {'tile': tile, 'text': logfile.getvalue()}

# %%
tile = 'TILE-64N126E'
year = 2021
agg_res = 0.25
kwargs = dict(
              model_depth=model_depth, 
              model_bgc=model_bgc, 
              history_depth=history_depth,
              history_bgc=history_bgc,
              model_agcc=model_agcc, 
              history_agcc=history_agcc,              
              agg_res=agg_res)

predict_model(tile, year, local_path, **kwargs, logfile=False)
# Out:
# 		--------------- TILE-64N126E: 40323975 pixels burned ---------------
# MOD44B_VCF is not available for 2021, replaced by 2020
#
#  *** 40323975 pixels burned: Use DASK ---------------
# Sending large graph of size 38.46 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
# 		+++++ Files are saved +++++
# {'tile': 'TILE-64N126E',
#  'text': '\n\t\t--------------- TILE-64N126E: 40323975 pixels burned ---------------\n\n *** 40323975 pixels burned: Use DASK ---------------\n\t\t+++++ Files are saved +++++\n\n'}

# %%
agg_res = 0.25
kwargs = dict(
              model_depth=model_depth, 
              model_bgc=model_bgc, 
              history_depth=history_depth,
              history_bgc=history_bgc,
              model_agcc=model_agcc, 
              history_agcc=history_agcc,              
              agg_res=agg_res)
LogFile = open(f'{local_path}/PeatFire/Logs/Logfile_PeatFire_AGCC_Predictions_{str(agg_res).replace(".", "")}D.txt', 'w')
# LogFile.write(f'{30 * "-"} LogFile of prediction ofAGCC of PeatFires {agg_res}° {30 * "-"}\n\n')
Tiles = os.listdir(f'{local_path}/PeatFire/ByTile')
Years = range(2023, 2000, -1)
time0 = datetime.now()
for year in Years[:]:
    time1 = datetime.now()
    Global_Functions.print_and_log(LogFile, f'\n\n{10 * "#"} Processing of Year: {year} {10 * "#"}\n\n')
    listdict = Parallel(n_jobs=2, verbose=100, backend='threading') (delayed (predict_model) (tile, year, local_path, **kwargs) for tile in Tiles[:])
    listdict.sort(key=operator.itemgetter('tile'))
    [LogFile.write(listdict[i]['text']) for i in range(len(listdict))]
    time2 = datetime.now()
    delta = time2 - time1
    hours, minutes, seconds = Global_Functions.convert_timedelta(delta)
    Global_Functions.print_and_log(LogFile, '\n\n%s Year %s is processed in %s hours, %s minutes, %s seconds %s '
                              %(10 *'+', year, hours, minutes, seconds, 10 * '+'))    
timef = datetime.now()
delta = timef - time0    
hours, minutes, seconds = Global_Functions.convert_timedelta(delta)
Global_Functions.print_and_log(LogFile, '\n\n%s FINISHED in %s hours, %s minutes, %s seconds %s'
                          %(20 *'-', hours, minutes, seconds, 20 * '-'))    
LogFile.close()
# Out:
# ########## Processing of Year: 2023 ##########
#
#
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
#
# 		--------------- TILE-60N111E: 16546 pixels burned ---------------
#
# 		--------------- TILE-68N132E: 5246 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:   19.5s
#
# 		--------------- TILE-70N123E: 2475 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:   20.9s
#
# 		--------------- TILE-70N141E: 9611 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:   38.4s
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:   39.6s
#
# 		--------------- TILE-60N108E: 12587 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
#
# 		--------------- TILE-70N177E: 582 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:   58.6s
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:   58.6s
#
# 		--------------- TILE-62N111E: 71636 pixels burned ---------------
#
# 		--------------- TILE-70N075E: 659 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:  1.3min
#
# 		--------------- TILE-68N084E: 59 pixels burned ---------------
#
# 		--------------- TILE-66N090E: 210143 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:  1.6min
#
# 		--------------- TILE-64N117E: 25023 pixels burned ---------------
#
# 		--------------- TILE-62N093E: 0 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:  1.7min
#
# 		--------------- TILE-72N117E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:  1.7min
#
# 		--------------- TILE-72N105E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:  1.8min
#
# 		--------------- TILE-70N126E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:  1.8min
#
# 		--------------- TILE-62N153E: 190898 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:  2.0min
#
# 		--------------- TILE-62N165E: 178089 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:  2.1min
#
# 		--------------- TILE-64N120E: 25996 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:  2.3min
#
# 		--------------- TILE-70N078E: 2642 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:  2.4min
#
# 		--------------- TILE-60N093E: 6301 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:  2.6min
#
# 		--------------- TILE-70N066E: 9638 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:  2.7min
#
# 		--------------- TILE-64N126E: 11481 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:  2.9min
#
# 		--------------- TILE-68N117E: 3571 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:  3.0min
#
# 		--------------- TILE-64N096E: 4407 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:  3.2min
#
# 		--------------- TILE-60N156E: 27 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:  3.3min
#
# 		--------------- TILE-70N156E: 7938 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:  3.5min
#
# 		--------------- TILE-66N117E: 472995 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:  3.6min
#
# 		--------------- TILE-64N105E: 3494 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:  3.9min
#
# 		--------------- TILE-64N063E: 618848 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:  3.9min
#
# 		--------------- TILE-60N066E: 575780 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:  4.2min
#
# 		--------------- TILE-64N108E: 47326 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:  4.2min
#
# 		--------------- TILE-66N111E: 734 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:  4.5min
#
# 		--------------- TILE-68N144E: 192107 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:  4.5min
#
# 		--------------- TILE-62N108E: 47 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:  4.8min
#
# 		--------------- TILE-64N069E: 327410 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:  4.8min
#
# 		--------------- TILE-64N129E: 19814 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:  5.1min
#
# 		--------------- TILE-74N105E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:  5.1min
#
# 		--------------- TILE-60N129E: 1607508 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:  5.2min
#
# 		--------------- TILE-66N096E: 10513 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:  5.5min
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:  5.5min
#
# 		--------------- TILE-70N153E: 4906 pixels burned ---------------
#
# 		--------------- TILE-70N165E: 1090 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:  5.8min
# 		+++++ Files are saved +++++
#
#
# 		--------------- TILE-64N138E: 21053 pixels burned ---------------
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:  5.8min
#
# 		--------------- TILE-62N126E: 30749 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:  6.1min
#
# 		--------------- TILE-68N129E: 329 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:  6.1min
# MOD44B_VCF is not available for 2023, replaced by 2020
#
# 		--------------- TILE-62N066E: 394878 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:  6.4min
#
# 		--------------- TILE-64N168E: 348137 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:  6.4min
#
# 		--------------- TILE-60N141E: 954729 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:  6.7min
#
# 		--------------- TILE-74N108E: 0 pixels burned ---------------		+++++ Files are saved +++++
#
#
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:  6.7min
#
# 		--------------- TILE-62N099E: 128 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  48 tasks      | elapsed:  6.8min
#
# 		--------------- TILE-60N132E: 2792741 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  49 tasks      | elapsed:  7.1min
#
# 		--------------- TILE-68N126E: 1241 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  50 tasks      | elapsed:  7.1min
#
# 		--------------- TILE-70N159E: 1628 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  51 tasks      | elapsed:  7.3min
#
# 		--------------- TILE-62N138E: 903094 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  52 tasks      | elapsed:  7.4min
#
# 		--------------- TILE-68N105E: 3111 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  53 tasks      | elapsed:  7.7min
#
# 		--------------- TILE-70N087E: 15930 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  54 tasks      | elapsed:  7.7min
#
# 		--------------- TILE-74N078E: 136 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  55 tasks      | elapsed:  8.0min
#
# 		--------------- TILE-62N084E: 27 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  56 tasks      | elapsed:  8.0min
#
# 		--------------- TILE-72N087E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  57 tasks      | elapsed:  8.1min
#
# 		--------------- TILE-74N099E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  58 tasks      | elapsed:  8.1min
#
# 		--------------- TILE-74N138E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  59 tasks      | elapsed:  8.2min
#
# 		--------------- TILE-62N123E: 2859 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  60 tasks      | elapsed:  8.4min
#
# 		--------------- TILE-74N081E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  61 tasks      | elapsed:  8.4min
#
# 		--------------- TILE-68N174E: 1614 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  62 tasks      | elapsed:  8.5min
#
# 		--------------- TILE-64N162E: 515 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  63 tasks      | elapsed:  8.7min
#
# 		--------------- TILE-66N069E: 123992 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  64 tasks      | elapsed:  8.8min
#
# 		--------------- TILE-64N141E: 290499 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  65 tasks      | elapsed:  9.0min
#
# 		--------------- TILE-72N129E: 120057 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  66 tasks      | elapsed:  9.1min
#
# 		--------------- TILE-72N078E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  67 tasks      | elapsed:  9.2min
#
# 		--------------- TILE-64N099E: 14401 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  68 tasks      | elapsed:  9.4min
#
# 		--------------- TILE-72N084E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  69 tasks      | elapsed:  9.4min
#
# 		--------------- TILE-72N111E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  70 tasks      | elapsed:  9.5min
#
# 		--------------- TILE-64N087E: 49511 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  71 tasks      | elapsed:  9.5min
#
# 		--------------- TILE-62N159E: 211961 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  72 tasks      | elapsed:  9.8min
#
# 		--------------- TILE-66N150E: 2181477 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  73 tasks      | elapsed:  9.8min
#
# 		--------------- TILE-64N135E: 117214 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  74 tasks      | elapsed: 10.1min
#
# 		--------------- TILE-60N150E: 485777 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  75 tasks      | elapsed: 10.1min
#
# 		--------------- TILE-72N081E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  76 tasks      | elapsed: 10.2min
#
# 		--------------- TILE-68N069E: 126396 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  77 tasks      | elapsed: 10.4min
#
# 		--------------- TILE-64N150E: 1861608 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  78 tasks      | elapsed: 10.5min
#
# 		--------------- TILE-66N168E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  79 tasks      | elapsed: 10.5min
#
# 		--------------- TILE-62N120E: 1701142 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  80 tasks      | elapsed: 10.8min
#
# 		--------------- TILE-70N138E: 4199 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  81 tasks      | elapsed: 10.8min
#
# 		--------------- TILE-68N147E: 844999 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  82 tasks      | elapsed: 11.1min
#
# 		--------------- TILE-64N078E: 54390 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  83 tasks      | elapsed: 11.1min
#
# 		--------------- TILE-66N099E: 77649 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  84 tasks      | elapsed: 11.4min
#
# 		--------------- TILE-70N072E: 292 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  85 tasks      | elapsed: 11.4min
#
# 		--------------- TILE-72N159E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  86 tasks      | elapsed: 11.5min
#
# 		--------------- TILE-60N081E: 646514 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  87 tasks      | elapsed: 11.7min
#
# 		--------------- TILE-62N147E: 2790476 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  88 tasks      | elapsed: 11.8min
#
# 		--------------- TILE-68N066E: 1653 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  89 tasks      | elapsed: 12.0min
#
# 		--------------- TILE-60N123E: 105760 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  90 tasks      | elapsed: 12.0min
#
# 		--------------- TILE-68N150E: 2982090 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  91 tasks      | elapsed: 12.3min
#
# 		--------------- TILE-74N093E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  92 tasks      | elapsed: 12.3min
#
# 		--------------- TILE-66N153E: 3183445 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  93 tasks      | elapsed: 12.4min
#
# 		--------------- TILE-64N084E: 54331 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  94 tasks      | elapsed: 12.7min
#
# 		--------------- TILE-60N090E: 28294 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  95 tasks      | elapsed: 12.7min
#
# 		--------------- TILE-68N090E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  96 tasks      | elapsed: 12.8min
#
# 		--------------- TILE-74N096E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  97 tasks      | elapsed: 12.8min
#
# 		--------------- TILE-64N144E: 790541 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  98 tasks      | elapsed: 13.0min
#
# 		--------------- TILE-68N177E: 21185 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done  99 tasks      | elapsed: 13.1min
#
# 		--------------- TILE-64N066E: 308611 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 100 tasks      | elapsed: 13.3min
#
# 		--------------- TILE-72N090E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 101 tasks      | elapsed: 13.4min
#
# 		--------------- TILE-72N144E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 102 tasks      | elapsed: 13.4min
#
# 		--------------- TILE-72N150E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 103 tasks      | elapsed: 13.5min
#
# 		--------------- TILE-62N171E: 1830 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 104 tasks      | elapsed: 13.5min
#
# 		--------------- TILE-66N177E: 1074 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 105 tasks      | elapsed: 13.8min
#
# 		--------------- TILE-60N138E: 1283757 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 106 tasks      | elapsed: 13.8min
#
# 		--------------- TILE-66N162E: 2734 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 107 tasks      | elapsed: 14.1min
#
# 		--------------- TILE-68N135E: 133257 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 108 tasks      | elapsed: 14.1min
# MOD44B_VCF is not available for 2023, replaced by 2020
#
# 		--------------- TILE-74N123E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 109 tasks      | elapsed: 14.1min
#
# 		--------------- TILE-60N096E: 17619 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 110 tasks      | elapsed: 14.4min
#
# 		--------------- TILE-64N147E: 285506 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 111 tasks      | elapsed: 14.4min
#
# 		--------------- TILE-66N174E: 17 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 112 tasks      | elapsed: 14.7min
#
# 		--------------- TILE-68N093E: 45204 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 113 tasks      | elapsed: 14.7min
#
# 		--------------- TILE-60N072E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 114 tasks      | elapsed: 14.8min
#
# 		--------------- TILE-64N174E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 115 tasks      | elapsed: 14.9min
#
# 		--------------- TILE-72N069E: 16584 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 116 tasks      | elapsed: 15.0min
#
# 		--------------- TILE-74N147E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 117 tasks      | elapsed: 15.1min
#
# 		--------------- TILE-66N087E: 32265 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 118 tasks      | elapsed: 15.2min
#
# 		--------------- TILE-70N114E: 1802 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 119 tasks      | elapsed: 15.4min
#
# 		--------------- TILE-70N099E: 701 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 120 tasks      | elapsed: 15.5min
#
# 		--------------- TILE-74N102E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 121 tasks      | elapsed: 15.5min
#
# 		--------------- TILE-66N171E: 136 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 122 tasks      | elapsed: 15.7min
#
# 		--------------- TILE-70N096E: 132 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 123 tasks      | elapsed: 15.8min
#
# 		--------------- TILE-68N162E: 18923 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 124 tasks      | elapsed: 16.0min
#
# 		--------------- TILE-60N120E: 140535 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 125 tasks      | elapsed: 16.1min
#
# 		--------------- TILE-72N108E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 126 tasks      | elapsed: 16.2min
#
# 		--------------- TILE-68N078E: 13794 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 127 tasks      | elapsed: 16.4min
#
# 		--------------- TILE-64N153E: 1620482 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 128 tasks      | elapsed: 16.5min
#
# 		--------------- TILE-66N105E: 145 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 129 tasks      | elapsed: 16.7min
#
# 		--------------- TILE-70N090E: 1250 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 130 tasks      | elapsed: 16.8min
#
# 		--------------- TILE-68N108E: 1079 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 131 tasks      | elapsed: 17.0min
#
# 		--------------- TILE-74N132E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 132 tasks      | elapsed: 17.0min
#
# 		--------------- TILE-62N087E: 9925 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 133 tasks      | elapsed: 17.1min
#
# 		--------------- TILE-64N171E: 2397 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 134 tasks      | elapsed: 17.3min
#
# 		--------------- TILE-64N132E: 23446 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 135 tasks      | elapsed: 17.4min
#
# 		--------------- TILE-68N120E: 68200 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 136 tasks      | elapsed: 17.6min
#
# 		--------------- TILE-68N153E: 4981607 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 137 tasks      | elapsed: 17.7min
#
# 		--------------- TILE-68N063E: 8493 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 138 tasks      | elapsed: 17.9min
#
# 		--------------- TILE-66N120E: 60091 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 139 tasks      | elapsed: 18.0min
#
# 		--------------- TILE-72N093E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 140 tasks      | elapsed: 18.1min
#
# 		--------------- TILE-60N117E: 202766 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 141 tasks      | elapsed: 18.3min
#
# 		--------------- TILE-66N081E: 11376 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 142 tasks      | elapsed: 18.4min
#
# 		--------------- TILE-64N093E: 91559 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 143 tasks      | elapsed: 18.6min
#
# 		--------------- TILE-70N147E: 6480 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 144 tasks      | elapsed: 18.7min
#
# 		--------------- TILE-72N066E: 11934 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 145 tasks      | elapsed: 18.9min
#
# 		--------------- TILE-70N069E: 125 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 146 tasks      | elapsed: 19.0min
#
# 		--------------- TILE-64N177E: 7144 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 147 tasks      | elapsed: 19.2min
#
# 		--------------- TILE-62N150E: 1604116 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 148 tasks      | elapsed: 19.2min
#
# 		--------------- TILE-62N162E: 288 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 149 tasks      | elapsed: 19.5min
#
# 		--------------- TILE-68N156E: 6297775 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 150 tasks      | elapsed: 19.5min
#
# 		--------------- TILE-60N078E: 1205798 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 151 tasks      | elapsed: 19.8min
#
# 		--------------- TILE-66N075E: 111143 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 152 tasks      | elapsed: 19.9min
#
# 		--------------- TILE-66N123E: 342296 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 153 tasks      | elapsed: 20.1min
#
# 		--------------- TILE-60N075E: 991192 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 154 tasks      | elapsed: 20.2min
#
# 		--------------- TILE-66N072E: 134598 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 155 tasks      | elapsed: 20.4min
#
# 		--------------- TILE-70N081E: 7496 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 156 tasks      | elapsed: 20.5min
#
# 		--------------- TILE-68N141E: 805655 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 157 tasks      | elapsed: 20.7min
#
# 		--------------- TILE-66N108E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 158 tasks      | elapsed: 20.8min
#
# 		--------------- TILE-66N144E: 188931 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 159 tasks      | elapsed: 20.8min
#
# 		--------------- TILE-66N129E: 406862 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 160 tasks      | elapsed: 21.1min
#
# 		--------------- TILE-68N087E: 2754 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 161 tasks      | elapsed: 21.1min
#
# 		--------------- TILE-70N102E: 1503 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 162 tasks      | elapsed: 21.4min
#
# 		--------------- TILE-68N081E: 15535 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 163 tasks      | elapsed: 21.4min
#
# 		--------------- TILE-60N063E: 1070531 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 164 tasks      | elapsed: 21.6min
#
# 		--------------- TILE-62N135E: 5510080 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 165 tasks      | elapsed: 21.8min
#
# 		--------------- TILE-66N135E: 124570 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 166 tasks      | elapsed: 22.0min
#
# 		--------------- TILE-68N096E: 6930 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 167 tasks      | elapsed: 22.0min
# MOD44B_VCF is not available for 2023, replaced by 2020
#
# 		--------------- TILE-72N141E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 168 tasks      | elapsed: 22.1min
#
# 		--------------- TILE-74N069E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 169 tasks      | elapsed: 22.1min
#
# 		--------------- TILE-64N081E: 12872 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 170 tasks      | elapsed: 22.3min
#
# 		--------------- TILE-68N075E: 86385 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 171 tasks      | elapsed: 22.4min
#
# 		--------------- TILE-62N156E: 675 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 172 tasks      | elapsed: 22.6min
#
# 		--------------- TILE-60N084E: 22136 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 173 tasks      | elapsed: 22.7min
#
# 		--------------- TILE-60N114E: 110385 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 174 tasks      | elapsed: 22.9min
#
# 		--------------- TILE-66N063E: 193148 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 175 tasks      | elapsed: 23.0min
#
# 		--------------- TILE-72N114E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 176 tasks      | elapsed: 23.1min
#
# 		--------------- TILE-72N072E: 44480 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 177 tasks      | elapsed: 23.3min
#
# 		--------------- TILE-60N135E: 7712582 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 178 tasks      | elapsed: 23.4min
#
# 		--------------- TILE-64N123E: 26013 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 179 tasks      | elapsed: 23.6min
#
# 		--------------- TILE-64N072E: 48474 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 180 tasks      | elapsed: 23.7min
#
# 		--------------- TILE-64N165E: 17390 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 181 tasks      | elapsed: 23.9min
#
# 		--------------- TILE-74N114E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 182 tasks      | elapsed: 24.0min
#
# 		--------------- TILE-72N132E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 183 tasks      | elapsed: 24.0min
#
# 		--------------- TILE-68N111E: 7129 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 184 tasks      | elapsed: 24.0min
# MOD44B_VCF is not available for 2023, replaced by 2020
#
# 		--------------- TILE-64N111E: 25558 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 185 tasks      | elapsed: 24.3min
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 186 tasks      | elapsed: 24.3min
#
# 		--------------- TILE-68N138E: 32360 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
#
# 		--------------- TILE-70N162E: 3738 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 187 tasks      | elapsed: 24.6min
#
# 		--------------- TILE-72N147E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 188 tasks      | elapsed: 24.6min
#
# 		--------------- TILE-72N075E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 189 tasks      | elapsed: 24.7min
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 190 tasks      | elapsed: 24.7min
#
# 		--------------- TILE-72N099E: 0 pixels burned ---------------
#
# 		--------------- TILE-68N114E: 35559 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 191 tasks      | elapsed: 24.8min
#
# 		--------------- TILE-62N105E: 27036 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 192 tasks      | elapsed: 25.0min
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 193 tasks      | elapsed: 25.1min
#
# 		--------------- TILE-74N129E: 0 pixels burned ---------------
#
# 		--------------- TILE-70N168E: 2728 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 194 tasks      | elapsed: 25.1min
#
# 		--------------- TILE-66N159E: 264091 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 195 tasks      | elapsed: 25.4min
#
# 		--------------- TILE-66N084E: 15344 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed: 25.4min
#
# 		--------------- TILE-68N072E: 85193 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 197 tasks      | elapsed: 25.7min
#
# 		--------------- TILE-66N138E: 480492 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 198 tasks      | elapsed: 25.7min
# MOD44B_VCF is not available for 2023, replaced by 2020
#
# 		--------------- TILE-66N093E: 153836 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 199 tasks      | elapsed: 26.0min
#
# 		--------------- TILE-68N102E: 3054 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 200 tasks      | elapsed: 26.0min
# MOD44B_VCF is not available for 2023, replaced by 2020
#
# 		--------------- TILE-62N117E: 215230 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 201 tasks      | elapsed: 26.3min
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 202 tasks      | elapsed: 26.3min
#
# 		--------------- TILE-60N162E: 0 pixels burned ---------------
#
# 		--------------- TILE-66N114E: 305238 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 203 tasks      | elapsed: 26.4min
#
# 		--------------- TILE-72N135E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 204 tasks      | elapsed: 26.4min
#
# 		--------------- TILE-64N075E: 60984 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 205 tasks      | elapsed: 26.7min
#
# 		--------------- TILE-72N126E: 51 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 206 tasks      | elapsed: 26.7min
#
# 		--------------- TILE-62N174E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 207 tasks      | elapsed: 26.8min
#
# 		--------------- TILE-66N102E: 65918 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 208 tasks      | elapsed: 27.0min
#
# 		--------------- TILE-70N174E: 655 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 209 tasks      | elapsed: 27.1min
#
# 		--------------- TILE-60N153E: 2309 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 210 tasks      | elapsed: 27.3min
#
# 		--------------- TILE-72N120E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 211 tasks      | elapsed: 27.3min
#
# 		--------------- TILE-74N072E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 212 tasks      | elapsed: 27.4min
#
# 		--------------- TILE-68N168E: 1982 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 213 tasks      | elapsed: 27.4min
#
# 		--------------- TILE-74N135E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 214 tasks      | elapsed: 27.5min
#
# 		--------------- TILE-72N102E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 215 tasks      | elapsed: 27.5min
#
# 		--------------- TILE-70N063E: 42 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 216 tasks      | elapsed: 27.7min
#
# 		--------------- TILE-72N123E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 217 tasks      | elapsed: 27.8min
#
# 		--------------- TILE-74N144E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 218 tasks      | elapsed: 27.8min
#
# 		--------------- TILE-72N153E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 219 tasks      | elapsed: 27.9min
#
# 		--------------- TILE-74N117E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 220 tasks      | elapsed: 27.9min
#
# 		--------------- TILE-68N159E: 462395 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 221 tasks      | elapsed: 27.9min
# MOD44B_VCF is not available for 2023, replaced by 2020
#
# 		--------------- TILE-74N126E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 222 tasks      | elapsed: 28.0min
#
# 		--------------- TILE-74N066E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 223 tasks      | elapsed: 28.1min
#
# 		--------------- TILE-64N156E: 353166 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 224 tasks      | elapsed: 28.3min
#
# 		--------------- TILE-66N078E: 73213 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 225 tasks      | elapsed: 28.3min
#
# 		--------------- TILE-68N165E: 3133 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 226 tasks      | elapsed: 28.6min
#
# 		--------------- TILE-70N120E: 1002 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 227 tasks      | elapsed: 28.6min
#
# 		--------------- TILE-62N081E: 9641 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 228 tasks      | elapsed: 28.9min
#
# 		--------------- TILE-60N105E: 41757 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 229 tasks      | elapsed: 28.9min
#
# 		--------------- TILE-70N129E: 147682 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 230 tasks      | elapsed: 29.1min
#
# 		--------------- TILE-72N156E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 231 tasks      | elapsed: 29.2min
#
# 		--------------- TILE-62N114E: 1099 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 232 tasks      | elapsed: 29.3min
#
# 		--------------- TILE-66N141E: 729752 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 233 tasks      | elapsed: 29.5min
#
# 		--------------- TILE-62N075E: 259922 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 234 tasks      | elapsed: 29.6min
#
# 		--------------- TILE-70N117E: 56 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 235 tasks      | elapsed: 29.8min
#
# 		--------------- TILE-62N168E: 70 pixels burned ---------------
# MOD44B_VCF is not available for 2023, replaced by 2020
# 		+++++ Files are saved +++++
#
# ...
#
# 		--------------- TILE-62N105E: 23538 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 192 tasks      | elapsed: 24.8min
# 		+++++ Files are saved +++++
#
#
# 		--------------- TILE-74N129E: 0 pixels burned ---------------
# [Parallel(n_jobs=2)]: Done 193 tasks      | elapsed: 24.8min
#
# 		--------------- TILE-70N168E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 194 tasks      | elapsed: 24.9min
#
# 		--------------- TILE-66N159E: 4363218 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 195 tasks      | elapsed: 24.9min
#
# 		--------------- TILE-66N084E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed: 25.0min
#
# 		--------------- TILE-68N072E: 234 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 197 tasks      | elapsed: 25.3min
#
# 		--------------- TILE-66N138E: 424344 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 198 tasks      | elapsed: 25.3min
#
# 		--------------- TILE-66N093E: 11551 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 199 tasks      | elapsed: 25.6min
#
# 		--------------- TILE-68N102E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 200 tasks      | elapsed: 25.7min
#
# 		--------------- TILE-62N117E: 1062632 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 201 tasks      | elapsed: 25.7min
#
# 		--------------- TILE-60N162E: 16 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 202 tasks      | elapsed: 26.0min
#
# 		--------------- TILE-66N114E: 645481 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 203 tasks      | elapsed: 26.0min
#
# 		--------------- TILE-72N135E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 204 tasks      | elapsed: 26.1min
#
# 		--------------- TILE-64N075E: 17171 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 205 tasks      | elapsed: 26.4min
#
# 		--------------- TILE-72N126E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 206 tasks      | elapsed: 26.4min
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 207 tasks      | elapsed: 26.4min
#
# 		--------------- TILE-62N174E: 0 pixels burned ---------------
#
# 		--------------- TILE-66N102E: 11937 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 208 tasks      | elapsed: 26.5min
#
# 		--------------- TILE-70N174E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 209 tasks      | elapsed: 26.5min
#
# 		--------------- TILE-60N153E: 253943 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 210 tasks      | elapsed: 26.8min
#
# 		--------------- TILE-72N120E: 96942 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 211 tasks      | elapsed: 26.9min
#
# 		--------------- TILE-74N072E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 212 tasks      | elapsed: 27.0min
#
# 		--------------- TILE-68N168E: 404 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 213 tasks      | elapsed: 27.2min
#
# 		--------------- TILE-74N135E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 214 tasks      | elapsed: 27.2min
#
# 		--------------- TILE-72N102E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 215 tasks      | elapsed: 27.3min
#
# 		--------------- TILE-70N063E: 36 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 216 tasks      | elapsed: 27.3min
#
# 		--------------- TILE-72N123E: 1673326 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 217 tasks      | elapsed: 27.6min
#
# 		--------------- TILE-74N144E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 218 tasks      | elapsed: 27.6min
#
# 		--------------- TILE-72N153E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 219 tasks      | elapsed: 27.7min
#
# 		--------------- TILE-74N117E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 220 tasks      | elapsed: 27.7min
#
# 		--------------- TILE-68N159E: 155833 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 221 tasks      | elapsed: 27.7min
#
# 		--------------- TILE-74N126E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 222 tasks      | elapsed: 27.8min
#
# 		--------------- TILE-74N066E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 223 tasks      | elapsed: 27.9min
#
# 		--------------- TILE-64N156E: 305251 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 224 tasks      | elapsed: 28.1min
#
# 		--------------- TILE-66N078E: 674 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 225 tasks      | elapsed: 28.2min
#
# 		--------------- TILE-68N165E: 151668 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 226 tasks      | elapsed: 28.4min
#
# 		--------------- TILE-70N120E: 10139 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 227 tasks      | elapsed: 28.5min
#
# 		--------------- TILE-62N081E: 110767 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 228 tasks      | elapsed: 28.7min
#
# 		--------------- TILE-60N105E: 48779 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 229 tasks      | elapsed: 28.8min
#
# 		--------------- TILE-70N129E: 536101 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 230 tasks      | elapsed: 29.1min
#
# 		--------------- TILE-72N156E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 231 tasks      | elapsed: 29.1min
#
# 		--------------- TILE-62N114E: 886966 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 232 tasks      | elapsed: 29.2min
#
# 		--------------- TILE-66N141E: 410842 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 233 tasks      | elapsed: 29.5min
#
# 		--------------- TILE-62N075E: 24577 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 234 tasks      | elapsed: 29.5min
#
# 		--------------- TILE-70N117E: 23309 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 235 tasks      | elapsed: 29.8min
#
# 		--------------- TILE-62N168E: 48 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 236 tasks      | elapsed: 29.8min
#
# 		--------------- TILE-60N087E: 49747 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 237 tasks      | elapsed: 30.1min
#
# 		--------------- TILE-70N150E: 416321 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 238 tasks      | elapsed: 30.2min
#
# 		--------------- TILE-70N084E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 239 tasks      | elapsed: 30.2min
#
# 		--------------- TILE-74N090E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 240 tasks      | elapsed: 30.3min
#
# 		--------------- TILE-66N165E: 815650 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 241 tasks      | elapsed: 30.5min
#
# 		--------------- TILE-74N075E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 242 tasks      | elapsed: 30.6min
#
# 		--------------- TILE-62N141E: 25080 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 243 tasks      | elapsed: 30.6min
#
# 		--------------- TILE-74N084E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 244 tasks      | elapsed: 30.7min
#
# 		--------------- TILE-62N063E: 34797 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 245 tasks      | elapsed: 30.9min
#
# 		--------------- TILE-60N147E: 259614 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 246 tasks      | elapsed: 31.0min
#
# 		--------------- TILE-68N123E: 203652 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 247 tasks      | elapsed: 31.2min
#
# 		--------------- TILE-62N069E: 4814 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 248 tasks      | elapsed: 31.3min
#
# 		--------------- TILE-62N096E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 249 tasks      | elapsed: 31.4min
#
# 		--------------- TILE-62N090E: 15706 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 250 tasks      | elapsed: 31.6min
#
# 		--------------- TILE-74N141E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 251 tasks      | elapsed: 31.6min
#
# 		--------------- TILE-74N120E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 252 tasks      | elapsed: 31.7min
#
# 		--------------- TILE-60N165E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 253 tasks      | elapsed: 31.7min
#
# 		--------------- TILE-70N105E: 79815 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed: 31.8min
#
# 		--------------- TILE-60N102E: 632119 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 255 tasks      | elapsed: 32.1min
#
# 		--------------- TILE-62N129E: 813468 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 256 tasks      | elapsed: 32.1min
#
# 		--------------- TILE-64N090E: 428 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 257 tasks      | elapsed: 32.4min
#
# 		--------------- TILE-70N093E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 258 tasks      | elapsed: 32.5min
#
# 		--------------- TILE-62N144E: 206649 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 259 tasks      | elapsed: 32.5min
#
# 		--------------- TILE-70N144E: 158773 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 260 tasks      | elapsed: 32.8min
#
# 		--------------- TILE-70N108E: 19959 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 261 tasks      | elapsed: 32.9min
#
# 		--------------- TILE-66N156E: 11358288 pixels burned ---------------
#
#  *** 11358288 pixels burned: Use DASK ---------------
# Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41957 instead
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 262 tasks      | elapsed: 33.2min
#
# 		--------------- TILE-62N072E: 31826 pixels burned ---------------
# Sending large graph of size 10.84 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 263 tasks      | elapsed: 33.5min
#
# 		--------------- TILE-66N126E: 1646943 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 264 tasks      | elapsed: 33.9min
#
# 		--------------- TILE-72N096E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 265 tasks      | elapsed: 33.9min
#
# 		--------------- TILE-62N132E: 76976 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 266 tasks      | elapsed: 33.9min
#
# 		--------------- TILE-64N102E: 1261 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 267 tasks      | elapsed: 34.2min
#
# 		--------------- TILE-74N111E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 268 tasks      | elapsed: 34.3min
#
# 		--------------- TILE-70N135E: 783211 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 269 tasks      | elapsed: 34.3min
#
# 		--------------- TILE-72N138E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 270 tasks      | elapsed: 34.4min
#
# 		--------------- TILE-66N066E: 21046 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 271 tasks      | elapsed: 34.7min
#
# 		--------------- TILE-74N087E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 272 tasks      | elapsed: 34.7min
#
# 		--------------- TILE-66N147E: 334637 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 273 tasks      | elapsed: 34.7min
#
# 		--------------- TILE-70N111E: 150565 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 274 tasks      | elapsed: 35.1min
#
# 		--------------- TILE-60N159E: 160696 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 275 tasks      | elapsed: 35.1min
#
# 		--------------- TILE-64N114E: 46862 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 276 tasks      | elapsed: 35.4min
#
# 		--------------- TILE-68N171E: 986 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 277 tasks      | elapsed: 35.5min
#
# 		--------------- TILE-70N171E: 4741 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 278 tasks      | elapsed: 35.8min
#
# 		--------------- TILE-70N132E: 3973466 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 279 tasks      | elapsed: 35.8min
#
# 		--------------- TILE-64N159E: 388965 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 280 tasks      | elapsed: 36.1min
#
# 		--------------- TILE-66N132E: 771394 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 281 tasks      | elapsed: 36.2min
#
# 		--------------- TILE-60N126E: 38827 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 282 tasks      | elapsed: 36.5min
#
# 		--------------- TILE-60N099E: 39784 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 283 tasks      | elapsed: 36.5min
#
# 		--------------- TILE-68N099E: 0 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 284 tasks      | elapsed: 36.5min
#
# 		--------------- TILE-62N078E: 18577 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 285 tasks      | elapsed: 36.8min
#
# 		--------------- TILE-60N144E: 51726 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 286 tasks      | elapsed: 36.9min
#
# 		--------------- TILE-62N102E: 10674 pixels burned ---------------
# 		+++++ Files are saved +++++
#
#
# 		--------------- TILE-60N069E: 5474 pixels burned ---------------
# 		+++++ Files are saved +++++
#
# 		+++++ Files are saved +++++
#
# [Parallel(n_jobs=2)]: Done 289 out of 289 | elapsed: 37.4min finished
#
#
# ++++++++++ Year 2001 is processed in 0.0 hours, 37.0 minutes, 23.006091000000197 seconds ++++++++++
#
#
# -------------------- FINISHED in 14.0 hours, 7.0 minutes, 56.942692999997234 seconds --------------------

# %% [markdown]
# ## Uncertainty

# %%
resid_bgcc = df.bg_c_combusted - df.pred_bgc
mask = np.isfinite(df.pred_agcc)
resid_cc = df.bg_c_combusted[mask] + df.ag_c_combusted[mask] - df.pred_agcc[mask] - df.pred_bgc[mask]
rmse_bgcc = np.sqrt(np.mean(np.square(resid_bgcc)))
rmse_cc = np.sqrt(np.mean(np.square(resid_cc)))
stats_resid_bgcc = np.mean(resid_bgcc), np.std(resid_bgcc)
stats_resid_cc = np.mean(resid_cc), np.std(resid_cc)
r2 = metrics.r2_score(df.bg_c_combusted[mask] + df.ag_c_combusted[mask], df.pred_agcc[mask] + df.pred_bgc[mask])
rmse_bgcc, rmse_cc, r2, stats_resid_cc
# Out:
# (1529.6419730067437,
#  1540.7816073697502,
#  0.19293226173807843,
#  (-78.46317001608372, 1538.7824708385322))

# %%
def get_uncertainty(year, stats_resid_bgcc, stats_resid_cc, #rmse_cc, rmse_bgcc, 
                    M=1000, length_scale=5000, nu=0.5, 
                    chunk_size=int(1e6), fire_type='ALL', logfile=False):
    if not logfile:
        logfile = io.StringIO()           

    kernel = Matern(length_scale=length_scale, nu=nu)
    xres, yres = 0.00025, -0.00025
    width, height = 12000, 8000
    transformer = pyproj.Transformer.from_crs(4326, 'North_Pole_Stereographic', always_xy=True)
    np.random.seed(42)
    sum_transformed_bgcc = np.zeros(M)
    sum_transformed_cc = np.zeros(M)
    for f in list(glob.glob(f'{local_path}/PeatFire/ByTile/**/Pixel/BA_Peatland_*_{year}.tif'))[:]:
        tile = f.split('/')[-3]
        # if tile == 'TILE-64N126E':
        area = Global_Functions.get_pixel_area(f, area_1d=True)
        BA = rio.open(f).read(1)
        xmin, ymax = int(tile[8:11])+xres/2, int(tile[5:7])+yres/2 
        tile_coords = np.arange(ymax, ymax+height*yres, yres), np.arange(xmin, xmin+width*xres, xres)
        if fire_type == 'ALL':
            idx = np.where(BA != 0)
        else:
            idx = np.where(BA > 0)
        N = len(idx[0])
        Global_Functions.print_and_log(logfile, f'\n\t\t{15 * "-"} {tile}: {N} samlpes {15 * "-"}')
        if N > 0:
            coords = np.column_stack([tile_coords[0][idx[0]], tile_coords[1][idx[1]]])
            polar_coords = np.column_stack(transformer.transform(coords[:, 1], coords[:, 0]))
            areas = area[idx[0]]
            # sigma2_cc = (rmse_cc*np.median(areas))**2
            # sigma2_bgcc = (rmse_bgcc*np.median(areas))**2
            sigma_bgcc = np.abs(np.random.normal(loc=stats_resid_bgcc[0], scale=stats_resid_bgcc[1], size=N))
            sigma_cc = np.abs(np.random.normal(loc=stats_resid_cc[0], scale=stats_resid_cc[1], size=N))
            n_inducing = min(N, M)
            inducing_idx = np.random.choice(N, n_inducing, replace=False)               
            points_inducing = polar_coords[inducing_idx]
            nystroem = Nystroem(
                kernel=kernel,
                n_components=n_inducing,
                random_state=42
            )
            nystroem.fit(points_inducing)        
    
            ## Process data in chunks
            for i in range(0, N, chunk_size):
                Global_Functions.print_and_log(logfile, f'\n\t\t ***{i}/{N}')
                coords_chunk = polar_coords[i:i + chunk_size]
                # areas_chunk_bgcc = areas[i:i + chunk_size] * rmse_bgcc
                # areas_chunk_cc = areas[i:i + chunk_size] * rmse_cc
                areas_chunk_bgcc = areas[i:i + chunk_size] * sigma_bgcc[i:i + chunk_size]
                areas_chunk_cc = areas[i:i + chunk_size] * sigma_cc[i:i + chunk_size]
                phi_bgcc = nystroem.transform(coords_chunk)
                phi_cc = nystroem.transform(coords_chunk)
                phi_weighted_bgcc = np.zeros((phi_cc.shape[0], M), dtype=phi_cc.dtype)
                phi_weighted_bgcc[:, :n_inducing] = phi_bgcc * areas_chunk_bgcc[:, np.newaxis]
                phi_weighted_cc = np.zeros((phi_cc.shape[0], M), dtype=phi_cc.dtype)
                phi_weighted_cc[:, :n_inducing] = phi_cc * areas_chunk_cc[:, np.newaxis]
                sum_transformed_bgcc += phi_weighted_bgcc.sum(axis=0)
                sum_transformed_cc += phi_weighted_cc.sum(axis=0)
                del phi_bgcc, phi_cc, phi_weighted_bgcc, phi_weighted_cc

    ## Compute total variance (σ² * ||sum(Φ)||²)  // Φ = K_nm @ K_mm_{-1/2}
    total_variance_bgcc = np.sum(sum_transformed_bgcc ** 2)
    total_variance_cc = np.sum(sum_transformed_cc ** 2)
    std_bgcc = np.sqrt(total_variance_bgcc)*1e-12         ## in Tg
    std_cc = np.sqrt(total_variance_cc)*1e-12         ## in Tg
    Global_Functions.print_and_log(logfile, f'\n\t\t +++ BGCC: {std_bgcc:06} Tg  //  CC: {std_cc:06} Tg')
    return {'BGCC': std_bgcc, 'CC': std_cc}

# %%
local_path = '/media/amin/DISK6T/PhD/Landsat_BA/Siberia'
kwargs = dict(
              M=1000, length_scale=25000, 
              # rmse_cc=rmse_bgcc, rmse_bgcc=rmse_bgcc,
              stats_resid_bgcc=stats_resid_bgcc, stats_resid_cc=stats_resid_cc,
              nu=1.5, chunk_size=int(1e6), fire_type='ALL',
              logfile=False
            )
get_uncertainty(2020, **kwargs)
# Out:
# 		--------------- TILE-64N126E: 2959997 samlpes ---------------
#
# 		 ***0/2959997
#
# 		 ***1000000/2959997
#
# 		 ***2000000/2959997
#
# 		 +++ BGCC: 0.8144141660041515 Tg  //  CC: 0.8199975035453122 Tg
# {'BGCC': 0.8144141660041515, 'CC': 0.8199975035453122}

# %%
local_path = '/media/amin/DISK6T/PhD/Landsat_BA/Siberia'
fire_type='ALL'
LogFile = open(f'{local_path}/PeatFire/Logs/Logfile_PeatFire_Emissions-{fire_type}_Uncertainty.txt', 'w')
LogFile.write(f'{30 * "-"} LogFile of prediction of {fire_type} Emissions of Uncertainty {30 * "-"}\n\n')
kwargs = dict(
              M=1000, length_scale=25000, 
              # rmse_cc=rmse_bgcc, rmse_bgcc=rmse_bgcc,
              stats_resid_bgcc=stats_resid_bgcc, stats_resid_cc=stats_resid_cc,
              nu=1.5, chunk_size=int(1e6), fire_type=fire_type,
              logfile=LogFile
            )
Years = range(2023, 2000, -1)
time0 = datetime.now()
df = {}
for year in Years[:]:
    time1 = datetime.now()
    Global_Functions.print_and_log(LogFile, f'\n\n{10 * "#"} Processing of Year: {year} {10 * "#"}\n\n')
    df[year] = get_uncertainty(year, **kwargs)
    time2 = datetime.now()
    delta = time2 - time1
    hours, minutes, seconds = Global_Functions.convert_timedelta(delta)
    Global_Functions.print_and_log(LogFile, '\n\n%s Year %s is processed in %s hours, %s minutes, %s seconds %s '
                              %(10 *'+', year, hours, minutes, seconds, 10 * '+'))    
timef = datetime.now()
delta = timef - time0    
hours, minutes, seconds = Global_Functions.convert_timedelta(delta)
Global_Functions.print_and_log(LogFile, '\n\n%s FINISHED in %s hours, %s minutes, %s seconds %s'
                          %(20 *'-', hours, minutes, seconds, 20 * '-'))    
LogFile.close()
# Out:
# ########## Processing of Year: 2023 ##########
#
#
#
# 		--------------- TILE-68N132E: 5246 samlpes ---------------
#
# 		 ***0/5246
#
# 		--------------- TILE-60N111E: 16546 samlpes ---------------
#
# 		 ***0/16546
#
# 		--------------- TILE-70N123E: 2458 samlpes ---------------
#
# 		 ***0/2458
#
# 		--------------- TILE-70N141E: 9519 samlpes ---------------
#
# 		 ***0/9519
#
# 		--------------- TILE-60N108E: 12565 samlpes ---------------
#
# 		 ***0/12565
#
# 		--------------- TILE-70N177E: 578 samlpes ---------------
#
# 		 ***0/578
#
# 		--------------- TILE-70N075E: 650 samlpes ---------------
#
# 		 ***0/650
#
# 		--------------- TILE-62N111E: 71636 samlpes ---------------
#
# 		 ***0/71636
#
# 		--------------- TILE-68N084E: 59 samlpes ---------------
#
# 		 ***0/59
#
# 		--------------- TILE-66N090E: 209685 samlpes ---------------
#
# 		 ***0/209685
#
# 		--------------- TILE-64N117E: 25023 samlpes ---------------
#
# 		 ***0/25023
#
# 		--------------- TILE-62N093E: 0 samlpes ---------------
#
# 		--------------- TILE-72N117E: 0 samlpes ---------------
#
# 		--------------- TILE-72N105E: 0 samlpes ---------------
#
# 		--------------- TILE-70N126E: 0 samlpes ---------------
#
# 		--------------- TILE-62N153E: 190860 samlpes ---------------
#
# 		 ***0/190860
#
# 		--------------- TILE-62N165E: 164574 samlpes ---------------
#
# 		 ***0/164574
#
# 		--------------- TILE-64N120E: 25980 samlpes ---------------
#
# 		 ***0/25980
#
# 		--------------- TILE-70N078E: 2615 samlpes ---------------
#
# 		 ***0/2615
#
# 		--------------- TILE-60N093E: 5934 samlpes ---------------
#
# 		 ***0/5934
#
# 		--------------- TILE-70N066E: 9616 samlpes ---------------
#
# 		 ***0/9616
#
# 		--------------- TILE-64N126E: 11472 samlpes ---------------
#
# 		 ***0/11472
#
# 		--------------- TILE-68N117E: 3571 samlpes ---------------
#
# 		 ***0/3571
#
# 		--------------- TILE-64N096E: 4407 samlpes ---------------
#
# 		 ***0/4407
#
# 		--------------- TILE-60N156E: 27 samlpes ---------------
#
# 		 ***0/27
#
# 		--------------- TILE-70N156E: 7122 samlpes ---------------
#
# 		 ***0/7122
#
# 		--------------- TILE-66N117E: 472085 samlpes ---------------
#
# 		 ***0/472085
#
# 		--------------- TILE-64N105E: 3494 samlpes ---------------
#
# 		 ***0/3494
#
# 		--------------- TILE-64N063E: 592079 samlpes ---------------
#
# 		 ***0/592079
#
# 		--------------- TILE-60N066E: 555842 samlpes ---------------
#
# 		 ***0/555842
#
# 		--------------- TILE-64N108E: 44730 samlpes ---------------
#
# 		 ***0/44730
#
# 		--------------- TILE-66N111E: 734 samlpes ---------------
#
# 		 ***0/734
#
# 		--------------- TILE-68N144E: 187587 samlpes ---------------
#
# 		 ***0/187587
#
# 		--------------- TILE-62N108E: 47 samlpes ---------------
#
# 		 ***0/47
#
# 		--------------- TILE-64N069E: 325012 samlpes ---------------
#
# 		 ***0/325012
#
# 		--------------- TILE-64N129E: 17929 samlpes ---------------
#
# 		 ***0/17929
#
# 		--------------- TILE-74N105E: 0 samlpes ---------------
#
# 		--------------- TILE-60N129E: 1606466 samlpes ---------------
#
# 		 ***0/1606466
#
# 		 ***1000000/1606466
#
# 		--------------- TILE-66N096E: 10507 samlpes ---------------
#
# 		 ***0/10507
#
# 		--------------- TILE-70N153E: 3276 samlpes ---------------
#
# 		 ***0/3276
#
# 		--------------- TILE-70N165E: 1090 samlpes ---------------
#
# 		 ***0/1090
#
# 		--------------- TILE-64N138E: 21001 samlpes ---------------
#
# 		 ***0/21001
#
# 		--------------- TILE-62N126E: 30526 samlpes ---------------
#
# 		 ***0/30526
#
# 		--------------- TILE-68N129E: 329 samlpes ---------------
#
# 		 ***0/329
#
# 		--------------- TILE-62N066E: 387214 samlpes ---------------
#
# 		 ***0/387214
#
# 		--------------- TILE-64N168E: 347775 samlpes ---------------
#
# 		 ***0/347775
#
# 		--------------- TILE-60N141E: 954502 samlpes ---------------
#
# 		 ***0/954502
#
# 		--------------- TILE-74N108E: 0 samlpes ---------------
#
# 		--------------- TILE-62N099E: 128 samlpes ---------------
#
# 		 ***0/128
#
# 		--------------- TILE-60N132E: 2792234 samlpes ---------------
#
# 		 ***0/2792234
#
# 		 ***1000000/2792234
#
# 		 ***2000000/2792234
#
# 		--------------- TILE-68N126E: 1241 samlpes ---------------
#
# 		 ***0/1241
#
# 		--------------- TILE-70N159E: 1176 samlpes ---------------
#
# 		 ***0/1176
#
# 		--------------- TILE-62N138E: 897696 samlpes ---------------
#
# 		 ***0/897696
#
# 		--------------- TILE-68N105E: 3111 samlpes ---------------
#
# 		 ***0/3111
#
# 		--------------- TILE-70N087E: 14414 samlpes ---------------
#
# 		 ***0/14414
#
# 		--------------- TILE-74N078E: 136 samlpes ---------------
#
# 		 ***0/136
#
# 		--------------- TILE-62N084E: 27 samlpes ---------------
#
# 		 ***0/27
#
# 		--------------- TILE-72N087E: 0 samlpes ---------------
#
# 		--------------- TILE-74N099E: 0 samlpes ---------------
#
# 		--------------- TILE-74N138E: 0 samlpes ---------------
#
# 		--------------- TILE-62N123E: 2859 samlpes ---------------
#
# 		 ***0/2859
#
# 		--------------- TILE-74N081E: 0 samlpes ---------------
#
# 		--------------- TILE-68N174E: 1460 samlpes ---------------
#
# 		 ***0/1460
#
# 		--------------- TILE-64N162E: 515 samlpes ---------------
#
# 		 ***0/515
#
# 		--------------- TILE-66N069E: 122390 samlpes ---------------
#
# 		 ***0/122390
#
# 		--------------- TILE-64N141E: 290237 samlpes ---------------
#
# 		 ***0/290237
#
# 		--------------- TILE-72N129E: 119956 samlpes ---------------
#
# 		 ***0/119956
#
# 		--------------- TILE-72N078E: 0 samlpes ---------------
#
# 		--------------- TILE-64N099E: 14337 samlpes ---------------
#
# 		 ***0/14337
#
# 		--------------- TILE-72N084E: 0 samlpes ---------------
#
# 		--------------- TILE-72N111E: 0 samlpes ---------------
#
# 		--------------- TILE-64N087E: 49479 samlpes ---------------
#
# 		 ***0/49479
#
# 		--------------- TILE-62N159E: 211692 samlpes ---------------
#
# 		 ***0/211692
#
# 		--------------- TILE-66N150E: 2129127 samlpes ---------------
#
# 		 ***0/2129127
#
# 		 ***1000000/2129127
#
# 		 ***2000000/2129127
#
# 		--------------- TILE-64N135E: 117128 samlpes ---------------
#
# 		 ***0/117128
#
# 		--------------- TILE-60N150E: 484596 samlpes ---------------
#
# 		 ***0/484596
#
# 		--------------- TILE-72N081E: 0 samlpes ---------------
#
# 		--------------- TILE-68N069E: 121523 samlpes ---------------
#
# 		 ***0/121523
#
# 		--------------- TILE-64N150E: 1859717 samlpes ---------------
#
# 		 ***0/1859717
#
# 		 ***1000000/1859717
#
# 		--------------- TILE-66N168E: 0 samlpes ---------------
#
# 		--------------- TILE-62N120E: 1700126 samlpes ---------------
#
# 		 ***0/1700126
#
# 		 ***1000000/1700126
#
# 		--------------- TILE-70N138E: 2963 samlpes ---------------
#
# 		 ***0/2963
#
# 		--------------- TILE-68N147E: 809462 samlpes ---------------
#
# 		 ***0/809462
#
# 		--------------- TILE-64N078E: 53825 samlpes ---------------
#
# 		 ***0/53825
#
# 		--------------- TILE-66N099E: 77637 samlpes ---------------
#
# 		 ***0/77637
#
# 		--------------- TILE-70N072E: 292 samlpes ---------------
#
# 		 ***0/292
#
# 		--------------- TILE-72N159E: 0 samlpes ---------------
#
# 		--------------- TILE-60N081E: 629217 samlpes ---------------
#
# 		 ***0/629217
#
# 		--------------- TILE-62N147E: 2788113 samlpes ---------------
#
# 		 ***0/2788113
#
# 		 ***1000000/2788113
#
# 		 ***2000000/2788113
#
# 		--------------- TILE-68N066E: 1522 samlpes ---------------
#
# 		 ***0/1522
#
# 		--------------- TILE-60N123E: 105110 samlpes ---------------
#
# 		 ***0/105110
#
# 		--------------- TILE-68N150E: 2880871 samlpes ---------------
#
# 		 ***0/2880871
#
# 		 ***1000000/2880871
#
# 		 ***2000000/2880871
#
# 		--------------- TILE-74N093E: 0 samlpes ---------------
#
# 		--------------- TILE-66N153E: 3177384 samlpes ---------------
#
# 		 ***0/3177384
#
# 		 ***1000000/3177384
#
# 		 ***2000000/3177384
#
# 		 ***3000000/3177384
#
# 		--------------- TILE-64N084E: 54331 samlpes ---------------
#
# 		 ***0/54331
#
# 		--------------- TILE-60N090E: 28057 samlpes ---------------
#
# 		 ***0/28057
#
# 		--------------- TILE-68N090E: 0 samlpes ---------------
#
# 		--------------- TILE-74N096E: 0 samlpes ---------------
#
# 		--------------- TILE-64N144E: 789778 samlpes ---------------
#
# 		 ***0/789778
#
# 		--------------- TILE-68N177E: 20056 samlpes ---------------
#
# 		 ***0/20056
#
# 		--------------- TILE-64N066E: 293652 samlpes ---------------
#
# 		 ***0/293652
#
# 		--------------- TILE-72N090E: 0 samlpes ---------------
#
# 		--------------- TILE-72N144E: 0 samlpes ---------------
#
# 		--------------- TILE-72N150E: 0 samlpes ---------------
#
# 		--------------- TILE-62N171E: 1830 samlpes ---------------
#
# 		 ***0/1830
#
# 		--------------- TILE-66N177E: 895 samlpes ---------------
#
# 		 ***0/895
#
# 		--------------- TILE-60N138E: 1280246 samlpes ---------------
#
# 		 ***0/1280246
#
# 		 ***1000000/1280246
#
# 		--------------- TILE-66N162E: 2672 samlpes ---------------
#
# 		 ***0/2672
#
# 		--------------- TILE-68N135E: 132863 samlpes ---------------
#
# 		 ***0/132863
#
# 		--------------- TILE-74N123E: 0 samlpes ---------------
#
# 		--------------- TILE-60N096E: 16911 samlpes ---------------
#
# 		 ***0/16911
#
# 		--------------- TILE-64N147E: 285380 samlpes ---------------
#
# 		 ***0/285380
#
# 		--------------- TILE-66N174E: 17 samlpes ---------------
#
# 		 ***0/17
#
# 		--------------- TILE-68N093E: 44907 samlpes ---------------
#
# 		 ***0/44907
#
# 		--------------- TILE-60N072E: 0 samlpes ---------------
#
# 		--------------- TILE-64N174E: 0 samlpes ---------------
#
# 		--------------- TILE-72N069E: 16485 samlpes ---------------
#
# 		 ***0/16485
#
# 		--------------- TILE-74N147E: 0 samlpes ---------------
#
# 		--------------- TILE-66N087E: 31987 samlpes ---------------
#
# 		 ***0/31987
#
# 		--------------- TILE-70N114E: 1802 samlpes ---------------
#
# 		 ***0/1802
#
# 		--------------- TILE-70N099E: 701 samlpes ---------------
#
# 		 ***0/701
#
# 		--------------- TILE-74N102E: 0 samlpes ---------------
#
# 		--------------- TILE-66N171E: 136 samlpes ---------------
#
# 		 ***0/136
#
# 		--------------- TILE-70N096E: 102 samlpes ---------------
#
# 		 ***0/102
#
# 		--------------- TILE-68N162E: 18789 samlpes ---------------
#
# 		 ***0/18789
#
# 		--------------- TILE-60N120E: 140444 samlpes ---------------
#
# 		 ***0/140444
#
# 		--------------- TILE-72N108E: 0 samlpes ---------------
#
# 		--------------- TILE-68N078E: 12782 samlpes ---------------
#
# 		 ***0/12782
#
# 		--------------- TILE-64N153E: 1617207 samlpes ---------------
#
# 		 ***0/1617207
#
# 		 ***1000000/1617207
#
# 		--------------- TILE-66N105E: 145 samlpes ---------------
#
# 		 ***0/145
#
# 		--------------- TILE-70N090E: 0 samlpes ---------------
#
# 		--------------- TILE-68N108E: 1079 samlpes ---------------
#
# 		 ***0/1079
#
# 		--------------- TILE-74N132E: 0 samlpes ---------------
#
# 		--------------- TILE-62N087E: 9898 samlpes ---------------
#
# 		 ***0/9898
#
# 		--------------- TILE-64N171E: 2397 samlpes ---------------
#
# 		 ***0/2397
#
# 		--------------- TILE-64N132E: 23357 samlpes ---------------
#
# 		 ***0/23357
#
# 		--------------- TILE-68N120E: 68200 samlpes ---------------
#
# 		 ***0/68200
#
# 		--------------- TILE-68N153E: 4974542 samlpes ---------------
#
# 		 ***0/4974542
#
# 		 ***1000000/4974542
#
# 		 ***2000000/4974542
#
# 		 ***3000000/4974542
#
# 		 ***4000000/4974542
#
# 		--------------- TILE-68N063E: 8430 samlpes ---------------
#
# 		 ***0/8430
#
# 		--------------- TILE-66N120E: 60090 samlpes ---------------
#
# 		 ***0/60090
#
# 		--------------- TILE-72N093E: 0 samlpes ---------------
#
# 		--------------- TILE-60N117E: 202225 samlpes ---------------
#
# 		 ***0/202225
#
# 		--------------- TILE-66N081E: 10581 samlpes ---------------
#
# 		 ***0/10581
#
# 		--------------- TILE-64N093E: 91559 samlpes ---------------
#
# 		 ***0/91559
#
# 		--------------- TILE-70N147E: 5899 samlpes ---------------
#
# 		 ***0/5899
#
# 		--------------- TILE-72N066E: 11446 samlpes ---------------
#
# 		 ***0/11446
#
# 		--------------- TILE-70N069E: 6 samlpes ---------------
#
# 		 ***0/6
#
# 		--------------- TILE-64N177E: 3731 samlpes ---------------
#
# 		 ***0/3731
#
# 		--------------- TILE-62N150E: 1600711 samlpes ---------------
#
# 		 ***0/1600711
#
# 		 ***1000000/1600711
#
# 		--------------- TILE-62N162E: 288 samlpes ---------------
#
# 		 ***0/288
#
# 		--------------- TILE-68N156E: 6291196 samlpes ---------------
#
# 		 ***0/6291196
#
# 		 ***1000000/6291196
#
# 		 ***2000000/6291196
#
# 		 ***3000000/6291196
#
# 		 ***4000000/6291196
#
# 		 ***5000000/6291196
#
# 		 ***6000000/6291196
#
# 		--------------- TILE-60N078E: 1169144 samlpes ---------------
#
# 		 ***0/1169144
#
# 		 ***1000000/1169144
#
# 		--------------- TILE-66N075E: 103768 samlpes ---------------
#
# 		 ***0/103768
#
# 		--------------- TILE-66N123E: 336345 samlpes ---------------
#
# 		 ***0/336345
#
# 		--------------- TILE-60N075E: 990964 samlpes ---------------
#
# 		 ***0/990964
#
# 		--------------- TILE-66N072E: 130655 samlpes ---------------
#
# 		 ***0/130655
#
# 		--------------- TILE-70N081E: 6821 samlpes ---------------
#
# 		 ***0/6821
#
# 		--------------- TILE-68N141E: 803077 samlpes ---------------
#
# 		 ***0/803077
#
# 		--------------- TILE-66N108E: 0 samlpes ---------------
#
# 		--------------- TILE-66N144E: 188866 samlpes ---------------
#
# 		 ***0/188866
#
# 		--------------- TILE-66N129E: 406385 samlpes ---------------
#
# 		 ***0/406385
#
# 		--------------- TILE-68N087E: 0 samlpes ---------------
#
# 		--------------- TILE-70N102E: 1168 samlpes ---------------
#
# 		 ***0/1168
#
# 		--------------- TILE-68N081E: 15178 samlpes ---------------
#
# 		 ***0/15178
#
# 		--------------- TILE-60N063E: 1027742 samlpes ---------------
#
# 		 ***0/1027742
#
# 		 ***1000000/1027742
#
# 		--------------- TILE-62N135E: 5499781 samlpes ---------------
#
# 		 ***0/5499781
#
# 		 ***1000000/5499781
#
# 		 ***2000000/5499781
#
# 		 ***3000000/5499781
#
# 		 ***4000000/5499781
#
# 		 ***5000000/5499781
#
# 		--------------- TILE-66N135E: 122485 samlpes ---------------
#
# 		 ***0/122485
#
# 		--------------- TILE-68N096E: 6930 samlpes ---------------
#
# 		 ***0/6930
#
# 		--------------- TILE-72N141E: 0 samlpes ---------------
#
# 		--------------- TILE-74N069E: 0 samlpes ---------------
#
# 		--------------- TILE-64N081E: 12858 samlpes ---------------
#
# 		 ***0/12858
#
# 		--------------- TILE-68N075E: 82804 samlpes ---------------
#
# 		 ***0/82804
#
# 		--------------- TILE-62N156E: 675 samlpes ---------------
#
# 		 ***0/675
#
# 		--------------- TILE-60N084E: 21618 samlpes ---------------
#
# 		 ***0/21618
#
# 		--------------- TILE-60N114E: 110385 samlpes ---------------
#
# 		 ***0/110385
#
# 		--------------- TILE-66N063E: 187860 samlpes ---------------
#
# 		 ***0/187860
#
# 		--------------- TILE-72N114E: 0 samlpes ---------------
#
# 		--------------- TILE-72N072E: 42505 samlpes ---------------
#
# 		 ***0/42505
#
# 		--------------- TILE-60N135E: 7704337 samlpes ---------------
#
# 		 ***0/7704337
#
# 		 ***1000000/7704337
#
# 		 ***2000000/7704337
#
# 		 ***3000000/7704337
#
# 		 ***4000000/7704337
#
# 		 ***5000000/7704337
#
# 		 ***6000000/7704337
#
# 		 ***7000000/7704337
#
# 		--------------- TILE-64N123E: 25870 samlpes ---------------
#
# 		 ***0/25870
#
# 		--------------- TILE-64N072E: 46340 samlpes ---------------
#
# 		 ***0/46340
#
# 		--------------- TILE-64N165E: 17336 samlpes ---------------
#
# 		 ***0/17336
#
# 		--------------- TILE-74N114E: 0 samlpes ---------------
#
# 		--------------- TILE-72N132E: 0 samlpes ---------------
#
# 		--------------- TILE-68N111E: 7129 samlpes ---------------
#
# 		 ***0/7129
#
# 		--------------- TILE-64N111E: 23438 samlpes ---------------
#
# 		 ***0/23438
#
# 		--------------- TILE-68N138E: 32359 samlpes ---------------
#
# 		 ***0/32359
#
# 		--------------- TILE-70N162E: 3738 samlpes ---------------
#
# 		 ***0/3738
#
# 		--------------- TILE-72N147E: 0 samlpes ---------------
#
# 		--------------- TILE-72N075E: 0 samlpes ---------------
#
# 		--------------- TILE-72N099E: 0 samlpes ---------------
#
# 		--------------- TILE-68N114E: 35553 samlpes ---------------
#
# 		 ***0/35553
#
# 		--------------- TILE-62N105E: 26952 samlpes ---------------
#
# 		 ***0/26952
#
# 		--------------- TILE-74N129E: 0 samlpes ---------------
#
# 		--------------- TILE-70N168E: 2709 samlpes ---------------
#
# 		 ***0/2709
#
# 		--------------- TILE-66N159E: 263943 samlpes ---------------
#
# 		 ***0/263943
#
# 		--------------- TILE-66N084E: 15069 samlpes ---------------
#
# 		 ***0/15069
#
# 		--------------- TILE-68N072E: 83103 samlpes ---------------
#
# 		 ***0/83103
#
# 		--------------- TILE-66N138E: 478618 samlpes ---------------
#
# 		 ***0/478618
#
# 		--------------- TILE-66N093E: 152934 samlpes ---------------
#
# 		 ***0/152934
#
# 		--------------- TILE-68N102E: 2849 samlpes ---------------
#
# 		 ***0/2849
#
# 		--------------- TILE-62N117E: 214065 samlpes ---------------
#
# 		 ***0/214065
#
# 		--------------- TILE-60N162E: 0 samlpes ---------------
#
# 		--------------- TILE-66N114E: 304984 samlpes ---------------
#
# 		 ***0/304984
#
# 		--------------- TILE-72N135E: 0 samlpes ---------------
#
# 		--------------- TILE-64N075E: 59523 samlpes ---------------
#
# 		 ***0/59523
#
# 		--------------- TILE-72N126E: 51 samlpes ---------------
#
# 		 ***0/51
#
# 		--------------- TILE-62N174E: 0 samlpes ---------------
#
# 		--------------- TILE-66N102E: 65713 samlpes ---------------
#
# 		 ***0/65713
#
# 		--------------- TILE-70N174E: 570 samlpes ---------------
#
# 		 ***0/570
#
# 		--------------- TILE-60N153E: 2309 samlpes ---------------
#
# 		 ***0/2309
#
# 		--------------- TILE-72N120E: 0 samlpes ---------------
#
# 		--------------- TILE-74N072E: 0 samlpes ---------------
#
# 		--------------- TILE-68N168E: 1007 samlpes ---------------
#
# 		 ***0/1007
#
# 		--------------- TILE-74N135E: 0 samlpes ---------------
#
# 		--------------- TILE-72N102E: 0 samlpes ---------------
#
# 		--------------- TILE-70N063E: 33 samlpes ---------------
#
# 		 ***0/33
#
# 		--------------- TILE-72N123E: 0 samlpes ---------------
#
# 		--------------- TILE-74N144E: 0 samlpes ---------------
#
# 		--------------- TILE-72N153E: 0 samlpes ---------------
#
# 		--------------- TILE-74N117E: 0 samlpes ---------------
#
# 		--------------- TILE-68N159E: 460926 samlpes ---------------
#
# 		 ***0/460926
#
# 		--------------- TILE-74N126E: 0 samlpes ---------------
#
# 		--------------- TILE-74N066E: 0 samlpes ---------------
#
# 		--------------- TILE-64N156E: 352480 samlpes ---------------
#
# 		 ***0/352480
#
# 		--------------- TILE-66N078E: 70750 samlpes ---------------
#
# 		 ***0/70750
#
# 		--------------- TILE-68N165E: 2986 samlpes ---------------
#
# 		 ***0/2986
#
# 		--------------- TILE-70N120E: 1002 samlpes ---------------
#
# 		 ***0/1002
#
# 		--------------- TILE-62N081E: 9641 samlpes ---------------
#
# 		 ***0/9641
#
# 		--------------- TILE-60N105E: 41757 samlpes ---------------
#
# 		 ***0/41757
#
# 		--------------- TILE-70N129E: 147574 samlpes ---------------
#
# 		 ***0/147574
#
# 		--------------- TILE-72N156E: 0 samlpes ---------------
#
# 		--------------- TILE-62N114E: 838 samlpes ---------------
#
# 		 ***0/838
#
# 		--------------- TILE-66N141E: 728420 samlpes ---------------
#
# 		 ***0/728420
#
# 		--------------- TILE-62N075E: 252628 samlpes ---------------
#
# 		 ***0/252628
#
# 		--------------- TILE-70N117E: 56 samlpes ---------------
#
# 		 ***0/56
#
# 		--------------- TILE-62N168E: 70 samlpes ---------------
#
# 		 ***0/70
#
# 		--------------- TILE-60N087E: 187416 samlpes ---------------
#
# 		 ***0/187416
#
# 		--------------- TILE-70N150E: 15810 samlpes ---------------
#
# 		 ***0/15810
#
# 		--------------- TILE-70N084E: 1569 samlpes ---------------
#
# 		 ***0/1569
#
# 		--------------- TILE-74N090E: 0 samlpes ---------------
#
# 		--------------- TILE-66N165E: 1105 samlpes ---------------
#
# 		 ***0/1105
#
# 		--------------- TILE-74N075E: 0 samlpes ---------------
#
# 		--------------- TILE-62N141E: 341883 samlpes ---------------
#
# 		 ***0/341883
#
# 		--------------- TILE-74N084E: 0 samlpes ---------------
#
# 		--------------- TILE-62N063E: 356336 samlpes ---------------
#
# 		 ***0/356336
#
# 		--------------- TILE-60N147E: 1279929 samlpes ---------------
#
# 		 ***0/1279929
#
# 		 ***1000000/1279929
#
# 		--------------- TILE-68N123E: 209 samlpes ---------------
#
# 		 ***0/209
#
# 		--------------- TILE-62N069E: 611826 samlpes ---------------
#
# 		 ***0/611826
#
# 		--------------- TILE-62N096E: 57664 samlpes ---------------
#
# 		 ***0/57664
#
# 		--------------- TILE-62N090E: 36532 samlpes ---------------
#
# 		 ***0/36532
#
# 		--------------- TILE-74N141E: 0 samlpes ---------------
#
# 		--------------- TILE-74N120E: 0 samlpes ---------------
#
# 		--------------- TILE-60N165E: 0 samlpes ---------------
#
# 		--------------- TILE-70N105E: 175 samlpes ---------------
#
# 		 ***0/175
#
# 		--------------- TILE-60N102E: 6709 samlpes ---------------
#
# 		 ***0/6709
#
# 		--------------- TILE-62N129E: 254732 samlpes ---------------
#
# 		 ***0/254732
#
# 		--------------- TILE-64N090E: 120754 samlpes ---------------
#
# 		 ***0/120754
#
# 		--------------- TILE-70N093E: 338 samlpes ---------------
#
# 		 ***0/338
#
# 		--------------- TILE-62N144E: 373257 samlpes ---------------
#
# 		 ***0/373257
#
# 		--------------- TILE-70N144E: 34160 samlpes ---------------
#
# 		 ***0/34160
#
# 		--------------- TILE-70N108E: 0 samlpes ---------------
#
# 		--------------- TILE-66N156E: 963613 samlpes ---------------
#
# 		 ***0/963613
#
# 		--------------- TILE-62N072E: 560796 samlpes ---------------
#
# 		 ***0/560796
#
# 		--------------- TILE-66N126E: 662 samlpes ---------------
#
# 		 ***0/662
#
# 		--------------- TILE-72N096E: 0 samlpes ---------------
#
# 		--------------- TILE-62N132E: 2805161 samlpes ---------------
#
# 		 ***0/2805161
#
# 		 ***1000000/2805161
#
# 		 ***2000000/2805161
#
# 		--------------- TILE-64N102E: 8032 samlpes ---------------
#
# 		 ***0/8032
#
# 		--------------- TILE-74N111E: 0 samlpes ---------------
#
# 		--------------- TILE-70N135E: 369 samlpes ---------------
#
# 		 ***0/369
#
# 		--------------- TILE-72N138E: 0 samlpes ---------------
#
# 		--------------- TILE-66N066E: 71213 samlpes ---------------
#
# 		 ***0/71213
#
# 		--------------- TILE-74N087E: 0 samlpes ---------------
#
# 		--------------- TILE-66N147E: 116277 samlpes ---------------
#
# 		 ***0/116277
#
# 		--------------- TILE-70N111E: 0 samlpes ---------------
#
# 		--------------- TILE-60N159E: 95189 samlpes ---------------
#
# 		 ***0/95189
#
# 		--------------- TILE-64N114E: 19116 samlpes ---------------
#
# 		 ***0/19116
#
# 		--------------- TILE-68N171E: 27 samlpes ---------------
#
# 		 ***0/27
#
# 		--------------- TILE-70N171E: 153 samlpes ---------------
#
# 		 ***0/153
#
# 		--------------- TILE-70N132E: 1978 samlpes ---------------
#
# 		 ***0/1978
#
# 		--------------- TILE-64N159E: 46562 samlpes ---------------
#
# 		 ***0/46562
#
# 		--------------- TILE-66N132E: 101 samlpes ---------------
#
# 		 ***0/101
#
# 		--------------- TILE-60N126E: 467719 samlpes ---------------
#
# 		 ***0/467719
#
# 		--------------- TILE-60N099E: 6745 samlpes ---------------
#
# 		 ***0/6745
#
# 		--------------- TILE-68N099E: 8665 samlpes ---------------
#
# 		 ***0/8665
#
# 		--------------- TILE-62N078E: 137341 samlpes ---------------
#
# 		 ***0/137341
#
# 		--------------- TILE-60N144E: 64832 samlpes ---------------
#
# 		 ***0/64832
#
# 		--------------- TILE-62N102E: 42130 samlpes ---------------
#
# 		 ***0/42130
#
# 		--------------- TILE-60N069E: 161992 samlpes ---------------
#
# 		 ***0/161992
#
# 		 +++ BGCC: 18.76548741240609 Tg  //  CC: 18.9001220130117 Tg
#
#
# ++++++++++ Year 2023 is processed in 1.0 hours, 5.0 minutes, 17.34081500000002 seconds ++++++++++
#
#
# ########## Processing of Year: 2022 ##########
#
#
#
# 		--------------- TILE-68N132E: 204055 samlpes ---------------
#
# 		 ***0/204055
#
# 		--------------- TILE-60N111E: 411 samlpes ---------------
#
# 		 ***0/411
#
# 		--------------- TILE-70N123E: 1633 samlpes ---------------
#
# 		 ***0/1633
#
# 		--------------- TILE-70N141E: 22293 samlpes ---------------
#
# 		 ***0/22293
#
# 		--------------- TILE-60N108E: 72428 samlpes ---------------
#
# 		 ***0/72428
#
# 		--------------- TILE-70N177E: 11341 samlpes ---------------
#
# 		 ***0/11341
#
# 		--------------- TILE-70N075E: 912 samlpes ---------------
#
# 		 ***0/912
#
# 		--------------- TILE-62N111E: 65326 samlpes ---------------
#
# 		 ***0/65326
#
# 		--------------- TILE-68N084E: 17810 samlpes ---------------
#
# 		 ***0/17810
#
# 		--------------- TILE-66N090E: 932 samlpes ---------------
#
# 		 ***0/932
#
# 		--------------- TILE-64N117E: 15020 samlpes ---------------
#
# 		 ***0/15020
#
# 		--------------- TILE-62N093E: 0 samlpes ---------------
#
# 		--------------- TILE-72N117E: 19509 samlpes ---------------
#
# 		 ***0/19509
#
# 		--------------- TILE-72N105E: 0 samlpes ---------------
#
# 		--------------- TILE-70N126E: 142820 samlpes ---------------
#
# 		 ***0/142820
#
# 		--------------- TILE-62N153E: 260591 samlpes ---------------
#
# 		 ***0/260591
#
# 		--------------- TILE-62N165E: 9437 samlpes ---------------
#
# 		 ***0/9437
#
# 		--------------- TILE-64N120E: 11064 samlpes ---------------
#
# 		 ***0/11064
#
# 		--------------- TILE-70N078E: 72394 samlpes ---------------
#
# 		 ***0/72394
#
# 		--------------- TILE-60N093E: 52382 samlpes ---------------
#
# 		 ***0/52382
#
# 		--------------- TILE-70N066E: 655 samlpes ---------------
#
# 		 ***0/655
#
# 		--------------- TILE-64N126E: 1135 samlpes ---------------
#
# 		 ***0/1135
#
# 		--------------- TILE-68N117E: 1040 samlpes ---------------
#
# 		 ***0/1040
#
# 		--------------- TILE-64N096E: 0 samlpes ---------------
#
# 		--------------- TILE-60N156E: 0 samlpes ---------------
#
# 		--------------- TILE-70N156E: 164790 samlpes ---------------
#
# 		 ***0/164790
#
# 		--------------- TILE-66N117E: 1085400 samlpes ---------------
#
# 		 ***0/1085400
#
# 		 ***1000000/1085400
#
# 		--------------- TILE-64N105E: 45457 samlpes ---------------
#
# 		 ***0/45457
#
# 		--------------- TILE-64N063E: 4285032 samlpes ---------------
#
# 		 ***0/4285032
#
# 		 ***1000000/4285032
#
# 		 ***2000000/4285032
#
# 		 ***3000000/4285032
#
# 		 ***4000000/4285032
#
# 		--------------- TILE-60N066E: 100327 samlpes ---------------
#
# 		 ***0/100327
#
# 		--------------- TILE-64N108E: 3672174 samlpes ---------------
#
# 		 ***0/3672174
#
# 		 ***1000000/3672174
#
# 		 ***2000000/3672174
#
# 		 ***3000000/3672174
#
# 		--------------- TILE-66N111E: 626461 samlpes ---------------
#
# 		 ***0/626461
#
# 		--------------- TILE-68N144E: 46137 samlpes ---------------
#
# 		 ***0/46137
#
# 		--------------- TILE-62N108E: 25202 samlpes ---------------
#
# 		 ***0/25202
#
# 		--------------- TILE-64N069E: 25209 samlpes ---------------
#
# 		 ***0/25209
#
# 		--------------- TILE-64N129E: 18801 samlpes ---------------
#
# 		 ***0/18801
#
# 		--------------- TILE-74N105E: 0 samlpes ---------------
#
# 		--------------- TILE-60N129E: 2015155 samlpes ---------------
#
# 		 ***0/2015155
#
# 		 ***1000000/2015155
#
# 		 ***2000000/2015155
#
# 		--------------- TILE-66N096E: 7421 samlpes ---------------
#
# 		 ***0/7421
#
# 		--------------- TILE-70N153E: 301118 samlpes ---------------
#
# 		 ***0/301118
#
# 		--------------- TILE-70N165E: 18480 samlpes ---------------
#
# 		 ***0/18480
#
# 		--------------- TILE-64N138E: 2597 samlpes ---------------
#
# 		 ***0/2597
#
# 		--------------- TILE-62N126E: 6884 samlpes ---------------
#
# 		 ***0/6884
#
# 		--------------- TILE-68N129E: 8972 samlpes ---------------
#
# 		 ***0/8972
#
# 		--------------- TILE-62N066E: 150965 samlpes ---------------
#
# 		 ***0/150965
#
# 		--------------- TILE-64N168E: 210173 samlpes ---------------
#
# 		 ***0/210173
#
# 		--------------- TILE-60N141E: 0 samlpes ---------------
#
# 		--------------- TILE-74N108E: 0 samlpes ---------------
#
# 		--------------- TILE-62N099E: 15250 samlpes ---------------
#
# 		 ***0/15250
#
# 		--------------- TILE-60N132E: 3870752 samlpes ---------------
#
# 		 ***0/3870752
#
# 		 ***1000000/3870752
#
# 		 ***2000000/3870752
#
# 		 ***3000000/3870752
#
# 		--------------- TILE-68N126E: 174 samlpes ---------------
#
# 		 ***0/174
#
# 		--------------- TILE-70N159E: 335771 samlpes ---------------
#
# 		 ***0/335771
#
# 		--------------- TILE-62N138E: 91372 samlpes ---------------
#
# 		 ***0/91372
#
# 		--------------- TILE-68N105E: 429665 samlpes ---------------
#
# 		 ***0/429665
#
# 		--------------- TILE-70N087E: 17724 samlpes ---------------
#
# 		 ***0/17724
#
# 		--------------- TILE-74N078E: 1359 samlpes ---------------
#
# 		 ***0/1359
#
# 		--------------- TILE-62N084E: 0 samlpes ---------------
#
# 		--------------- TILE-72N087E: 0 samlpes ---------------
#
# 		--------------- TILE-74N099E: 0 samlpes ---------------
#
# 		--------------- TILE-74N138E: 0 samlpes ---------------
#
# 		--------------- TILE-62N123E: 1507 samlpes ---------------
#
# 		 ***0/1507
#
# 		--------------- TILE-74N081E: 0 samlpes ---------------
#
# 		--------------- TILE-68N174E: 89816 samlpes ---------------
#
# 		 ***0/89816
#
# 		--------------- TILE-64N162E: 6052 samlpes ---------------
#
# 		 ***0/6052
#
# 		--------------- TILE-66N069E: 226995 samlpes ---------------
#
# 		 ***0/226995
#
# 		--------------- TILE-64N141E: 137899 samlpes ---------------
#
# 		 ***0/137899
#
# 		--------------- TILE-72N129E: 317464 samlpes ---------------
#
# 		 ***0/317464
#
# 		--------------- TILE-72N078E: 0 samlpes ---------------
#
# 		--------------- TILE-64N099E: 4708 samlpes ---------------
#
# 		 ***0/4708
#
# 		--------------- TILE-72N084E: 0 samlpes ---------------
#
# 		--------------- TILE-72N111E: 0 samlpes ---------------
#
# 		--------------- TILE-64N087E: 0 samlpes ---------------
#
# 		--------------- TILE-62N159E: 461 samlpes ---------------
#
# 		 ***0/461
#
# 		--------------- TILE-66N150E: 840 samlpes ---------------
#
# 		 ***0/840
#
# 		--------------- TILE-64N135E: 392081 samlpes ---------------
#
# 		 ***0/392081
#
# 		--------------- TILE-60N150E: 11103 samlpes ---------------
#
# 		 ***0/11103
#
# 		--------------- TILE-72N081E: 0 samlpes ---------------
#
# 		--------------- TILE-68N069E: 32641 samlpes ---------------
#
# 		 ***0/32641
#
# 		--------------- TILE-64N150E: 1248632 samlpes ---------------
#
# 		 ***0/1248632
#
# 		 ***1000000/1248632
#
# 		--------------- TILE-66N168E: 29363 samlpes ---------------
#
# 		 ***0/29363
#
# 		--------------- TILE-62N120E: 15442 samlpes ---------------
#
# 		 ***0/15442
#
# 		--------------- TILE-70N138E: 3740 samlpes ---------------
#
# 		 ***0/3740
#
# 		--------------- TILE-68N147E: 45630 samlpes ---------------
#
# 		 ***0/45630
#
# 		--------------- TILE-64N078E: 38982 samlpes ---------------
#
# 		 ***0/38982
#
# 		--------------- TILE-66N099E: 30912 samlpes ---------------
#
# 		 ***0/30912
#
# 		--------------- TILE-70N072E: 3550 samlpes ---------------
#
# 		 ***0/3550
#
# 		--------------- TILE-72N159E: 0 samlpes ---------------
#
# 		--------------- TILE-60N081E: 22692 samlpes ---------------
#
# 		 ***0/22692
#
# 		--------------- TILE-62N147E: 910053 samlpes ---------------
#
# 		 ***0/910053
#
# 		--------------- TILE-68N066E: 8491 samlpes ---------------
#
# 		 ***0/8491
#
# 		--------------- TILE-60N123E: 3438 samlpes ---------------
#
# 		 ***0/3438
#
# 		--------------- TILE-68N150E: 25484 samlpes ---------------
#
# 		 ***0/25484
#
# 		--------------- TILE-74N093E: 0 samlpes ---------------
#
# 		--------------- TILE-66N153E: 2092 samlpes ---------------
#
# 		 ***0/2092
#
# 		--------------- TILE-64N084E: 0 samlpes ---------------
#
# 		--------------- TILE-60N090E: 238489 samlpes ---------------
#
# 		 ***0/238489
#
# 		--------------- TILE-68N090E: 266 samlpes ---------------
#
# 		 ***0/266
#
# 		--------------- TILE-74N096E: 0 samlpes ---------------
#
# 		--------------- TILE-64N144E: 702340 samlpes ---------------
#
# 		 ***0/702340
#
# 		--------------- TILE-68N177E: 74651 samlpes ---------------
#
# 		 ***0/74651
#
# 		--------------- TILE-64N066E: 8237 samlpes ---------------
#
# 		 ***0/8237
#
# 		--------------- TILE-72N090E: 0 samlpes ---------------
#
# 		--------------- TILE-72N144E: 0 samlpes ---------------
#
# 		--------------- TILE-72N150E: 0 samlpes ---------------
#
# 		--------------- TILE-62N171E: 2514 samlpes ---------------
#
# 		 ***0/2514
#
# 		--------------- TILE-66N177E: 6053 samlpes ---------------
#
# 		 ***0/6053
#
# 		--------------- TILE-60N138E: 1052538 samlpes ---------------
#
# 		 ***0/1052538
#
# 		 ***1000000/1052538
#
# 		--------------- TILE-66N162E: 408 samlpes ---------------
#
# 		 ***0/408
#
# 		--------------- TILE-68N135E: 193789 samlpes ---------------
#
# 		 ***0/193789
#
# 		--------------- TILE-74N123E: 0 samlpes ---------------
#
# 		--------------- TILE-60N096E: 39143 samlpes ---------------
#
# 		 ***0/39143
#
# 		--------------- TILE-64N147E: 422455 samlpes ---------------
#
# 		 ***0/422455
#
# 		--------------- TILE-66N174E: 6776 samlpes ---------------
#
# 		 ***0/6776
#
# 		--------------- TILE-68N093E: 11697 samlpes ---------------
#
# 		 ***0/11697
#
# 		--------------- TILE-60N072E: 0 samlpes ---------------
#
# 		--------------- TILE-64N174E: 6293 samlpes ---------------
#
# 		 ***0/6293
#
# 		--------------- TILE-72N069E: 0 samlpes ---------------
#
# 		--------------- TILE-74N147E: 0 samlpes ---------------
#
# 		--------------- TILE-66N087E: 105 samlpes ---------------
#
# 		 ***0/105
#
# 		--------------- TILE-70N114E: 1429 samlpes ---------------
#
# 		 ***0/1429
#
# 		--------------- TILE-70N099E: 1366 samlpes ---------------
#
# 		 ***0/1366
#
# 		--------------- TILE-74N102E: 0 samlpes ---------------
#
# 		--------------- TILE-66N171E: 9023 samlpes ---------------
#
# 		 ***0/9023
#
# 		--------------- TILE-70N096E: 354 samlpes ---------------
#
# 		 ***0/354
#
# 		--------------- TILE-68N162E: 803981 samlpes ---------------
#
# 		 ***0/803981
#
# 		--------------- TILE-60N120E: 34559 samlpes ---------------
#
# 		 ***0/34559
#
# 		--------------- TILE-72N108E: 0 samlpes ---------------
#
# 		--------------- TILE-68N078E: 146476 samlpes ---------------
#
# 		 ***0/146476
#
# 		--------------- TILE-64N153E: 30703 samlpes ---------------
#
# 		 ***0/30703
#
# 		--------------- TILE-66N105E: 37498 samlpes ---------------
#
# 		 ***0/37498
#
# 		--------------- TILE-70N090E: 14885 samlpes ---------------
#
# 		 ***0/14885
#
# 		--------------- TILE-68N108E: 6454 samlpes ---------------
#
# 		 ***0/6454
#
# 		--------------- TILE-74N132E: 0 samlpes ---------------
#
# 		--------------- TILE-62N087E: 131 samlpes ---------------
#
# 		 ***0/131
#
# 		--------------- TILE-64N171E: 5472 samlpes ---------------
#
# 		 ***0/5472
#
# 		--------------- TILE-64N132E: 413428 samlpes ---------------
#
# 		 ***0/413428
#
# 		--------------- TILE-68N120E: 13477 samlpes ---------------
#
# 		 ***0/13477
#
# 		--------------- TILE-68N153E: 1927885 samlpes ---------------
#
# 		 ***0/1927885
#
# 		 ***1000000/1927885
#
# 		--------------- TILE-68N063E: 68199 samlpes ---------------
#
# 		 ***0/68199
#
# 		--------------- TILE-66N120E: 134957 samlpes ---------------
#
# 		 ***0/134957
#
# 		--------------- TILE-72N093E: 0 samlpes ---------------
#
# 		--------------- TILE-60N117E: 167861 samlpes ---------------
#
# 		 ***0/167861
#
# 		--------------- TILE-66N081E: 0 samlpes ---------------
#
# 		--------------- TILE-64N093E: 1378 samlpes ---------------
#
# 		 ***0/1378
#
# 		--------------- TILE-70N147E: 5337 samlpes ---------------
#
# 		 ***0/5337
#
# 		--------------- TILE-72N066E: 100 samlpes ---------------
#
# 		 ***0/100
#
# 		--------------- TILE-70N069E: 7469 samlpes ---------------
#
# 		 ***0/7469
#
# 		--------------- TILE-64N177E: 15768 samlpes ---------------
#
# 		 ***0/15768
#
# 		--------------- TILE-62N150E: 516250 samlpes ---------------
#
# 		 ***0/516250
#
# 		--------------- TILE-62N162E: 1528 samlpes ---------------
#
# 		 ***0/1528
#
# 		--------------- TILE-68N156E: 17300 samlpes ---------------
#
# 		 ***0/17300
#
# 		--------------- TILE-60N078E: 65059 samlpes ---------------
#
# 		 ***0/65059
#
# 		--------------- TILE-66N075E: 70843 samlpes ---------------
#
# 		 ***0/70843
#
# 		--------------- TILE-66N123E: 18084 samlpes ---------------
#
# 		 ***0/18084
#
# 		--------------- TILE-60N075E: 6688 samlpes ---------------
#
# 		 ***0/6688
#
# 		--------------- TILE-66N072E: 106992 samlpes ---------------
#
# 		 ***0/106992
#
# 		--------------- TILE-70N081E: 1259 samlpes ---------------
#
# 		 ***0/1259
#
# 		--------------- TILE-68N141E: 23685 samlpes ---------------
#
# 		 ***0/23685
#
# 		--------------- TILE-66N108E: 69268 samlpes ---------------
#
# 		 ***0/69268
#
# 		--------------- TILE-66N144E: 8174 samlpes ---------------
#
# 		 ***0/8174
#
# 		--------------- TILE-66N129E: 29583 samlpes ---------------
#
# 		 ***0/29583
#
# 		--------------- TILE-68N087E: 0 samlpes ---------------
#
# 		--------------- TILE-70N102E: 3147 samlpes ---------------
#
# 		 ***0/3147
#
# 		--------------- TILE-68N081E: 45343 samlpes ---------------
#
# 		 ***0/45343
#
# 		--------------- TILE-60N063E: 94919 samlpes ---------------
#
# 		 ***0/94919
#
# 		--------------- TILE-62N135E: 1597702 samlpes ---------------
#
# 		 ***0/1597702
#
# 		 ***1000000/1597702
#
# 		--------------- TILE-66N135E: 69669 samlpes ---------------
#
# 		 ***0/69669
#
# 		--------------- TILE-68N096E: 4196 samlpes ---------------
#
# 		 ***0/4196
#
# 		--------------- TILE-72N141E: 0 samlpes ---------------
#
# 		--------------- TILE-74N069E: 0 samlpes ---------------
#
# 		--------------- TILE-64N081E: 35047 samlpes ---------------
#
# 		 ***0/35047
#
# 		--------------- TILE-68N075E: 301922 samlpes ---------------
#
# 		 ***0/301922
#
# 		--------------- TILE-62N156E: 28 samlpes ---------------
#
# 		 ***0/28
#
# 		--------------- TILE-60N084E: 5659 samlpes ---------------
#
# 		 ***0/5659
#
# 		--------------- TILE-60N114E: 58370 samlpes ---------------
#
# 		 ***0/58370
#
# 		--------------- TILE-66N063E: 247806 samlpes ---------------
#
# 		 ***0/247806
#
# 		--------------- TILE-72N114E: 871 samlpes ---------------
#
# 		 ***0/871
#
# 		--------------- TILE-72N072E: 294 samlpes ---------------
#
# 		 ***0/294
#
# 		--------------- TILE-60N135E: 6192956 samlpes ---------------
#
# 		 ***0/6192956
#
# 		 ***1000000/6192956
#
# 		 ***2000000/6192956
#
# 		 ***3000000/6192956
#
# 		 ***4000000/6192956
#
# 		 ***5000000/6192956
#
# 		 ***6000000/6192956
#
# 		--------------- TILE-64N123E: 1287 samlpes ---------------
#
# 		 ***0/1287
#
# 		--------------- TILE-64N072E: 11539 samlpes ---------------
#
# 		 ***0/11539
#
# 		--------------- TILE-64N165E: 25837 samlpes ---------------
#
# 		 ***0/25837
#
# 		--------------- TILE-74N114E: 43 samlpes ---------------
#
# 		 ***0/43
#
# 		--------------- TILE-72N132E: 86408 samlpes ---------------
#
# 		 ***0/86408
#
# 		--------------- TILE-68N111E: 30133 samlpes ---------------
#
# 		 ***0/30133
#
# 		--------------- TILE-64N111E: 276206 samlpes ---------------
#
# 		 ***0/276206
#
# 		--------------- TILE-68N138E: 10243 samlpes ---------------
#
# 		 ***0/10243
#
# 		--------------- TILE-70N162E: 21720 samlpes ---------------
#
# 		 ***0/21720
#
# 		--------------- TILE-72N147E: 0 samlpes ---------------
#
# 		--------------- TILE-72N075E: 0 samlpes ---------------
#
# 		--------------- TILE-72N099E: 0 samlpes ---------------
#
# 		--------------- TILE-68N114E: 2483 samlpes ---------------
#
# 		 ***0/2483
#
# 		--------------- TILE-62N105E: 32649 samlpes ---------------
#
# 		 ***0/32649
#
# 		--------------- TILE-74N129E: 0 samlpes ---------------
#
# 		--------------- TILE-70N168E: 13552 samlpes ---------------
#
# 		 ***0/13552
#
# 		--------------- TILE-66N159E: 192837 samlpes ---------------
#
# 		 ***0/192837
#
# 		--------------- TILE-66N084E: 112 samlpes ---------------
#
# 		 ***0/112
#
# 		--------------- TILE-68N072E: 69849 samlpes ---------------
#
# 		 ***0/69849
#
# 		--------------- TILE-66N138E: 10464 samlpes ---------------
#
# 		 ***0/10464
#
# 		--------------- TILE-66N093E: 3263 samlpes ---------------
#
# 		 ***0/3263
#
# 		--------------- TILE-68N102E: 2892 samlpes ---------------
#
# 		 ***0/2892
#
# 		--------------- TILE-62N117E: 26628 samlpes ---------------
#
# 		 ***0/26628
#
# 		--------------- TILE-60N162E: 0 samlpes ---------------
#
# 		--------------- TILE-66N114E: 273465 samlpes ---------------
#
# 		 ***0/273465
#
# 		--------------- TILE-72N135E: 303557 samlpes ---------------
#
# 		 ***0/303557
#
# 		--------------- TILE-64N075E: 48059 samlpes ---------------
#
# 		 ***0/48059
#
# 		--------------- TILE-72N126E: 1911 samlpes ---------------
#
# 		 ***0/1911
#
# 		--------------- TILE-62N174E: 76 samlpes ---------------
#
# 		 ***0/76
#
# 		--------------- TILE-66N102E: 4805 samlpes ---------------
#
# 		 ***0/4805
#
# 		--------------- TILE-70N174E: 9707 samlpes ---------------
#
# 		 ***0/9707
#
# 		--------------- TILE-60N153E: 0 samlpes ---------------
#
# 		--------------- TILE-72N120E: 0 samlpes ---------------
#
# 		--------------- TILE-74N072E: 0 samlpes ---------------
#
# 		--------------- TILE-68N168E: 10103 samlpes ---------------
#
# 		 ***0/10103
#
# 		--------------- TILE-74N135E: 0 samlpes ---------------
#
# 		--------------- TILE-72N102E: 0 samlpes ---------------
#
# 		--------------- TILE-70N063E: 670 samlpes ---------------
#
# 		 ***0/670
#
# 		--------------- TILE-72N123E: 0 samlpes ---------------
#
# 		--------------- TILE-74N144E: 0 samlpes ---------------
#
# 		--------------- TILE-72N153E: 0 samlpes ---------------
#
# 		--------------- TILE-74N117E: 30489 samlpes ---------------
#
# 		 ***0/30489
#
# 		--------------- TILE-68N159E: 685797 samlpes ---------------
#
# 		 ***0/685797
#
# 		--------------- TILE-74N126E: 0 samlpes ---------------
#
# 		--------------- TILE-74N066E: 0 samlpes ---------------
#
# 		--------------- TILE-64N156E: 157938 samlpes ---------------
#
# 		 ***0/157938
#
# 		--------------- TILE-66N078E: 8006 samlpes ---------------
#
# 		 ***0/8006
#
# 		--------------- TILE-68N165E: 11869 samlpes ---------------
#
# 		 ***0/11869
#
# 		--------------- TILE-70N120E: 55 samlpes ---------------
#
# 		 ***0/55
#
# 		--------------- TILE-62N081E: 7313 samlpes ---------------
#
# 		 ***0/7313
#
# 		--------------- TILE-60N105E: 41572 samlpes ---------------
#
# 		 ***0/41572
#
# 		--------------- TILE-70N129E: 51417 samlpes ---------------
#
# 		 ***0/51417
#
# 		--------------- TILE-72N156E: 0 samlpes ---------------
#
# 		--------------- TILE-62N114E: 26785 samlpes ---------------
#
# 		 ***0/26785
#
# 		--------------- TILE-66N141E: 21790 samlpes ---------------
#
# 		 ***0/21790
#
# 		--------------- TILE-62N075E: 75177 samlpes ---------------
#
# 		 ***0/75177
#
# 		--------------- TILE-70N117E: 1642 samlpes ---------------
#
# 		 ***0/1642
#
# 		--------------- TILE-62N168E: 64 samlpes ---------------
#
# 		 ***0/64
#
# 		--------------- TILE-60N087E: 11652 samlpes ---------------
#
# 		 ***0/11652
#
# 		--------------- TILE-70N150E: 26097 samlpes ---------------
#
# 		 ***0/26097
#
# 		--------------- TILE-70N084E: 2625 samlpes ---------------
#
# 		 ***0/2625
#
# 		--------------- TILE-74N090E: 0 samlpes ---------------
#
# 		--------------- TILE-66N165E: 41421 samlpes ---------------
#
# 		 ***0/41421
#
# 		--------------- TILE-74N075E: 0 samlpes ---------------
#
# 		--------------- TILE-62N141E: 405887 samlpes ---------------
#
# 		 ***0/405887
#
# 		--------------- TILE-74N084E: 0 samlpes ---------------
#
# 		--------------- TILE-62N063E: 2677100 samlpes ---------------
#
# 		 ***0/2677100
#
# 		 ***1000000/2677100
#
# 		 ***2000000/2677100
#
# 		--------------- TILE-60N147E: 27240 samlpes ---------------
#
# 		 ***0/27240
#
# 		--------------- TILE-68N123E: 3594 samlpes ---------------
#
# 		 ***0/3594
#
# 		--------------- TILE-62N069E: 108096 samlpes ---------------
#
# 		 ***0/108096
#
# 		--------------- TILE-62N096E: 40596 samlpes ---------------
#
# 		 ***0/40596
#
# 		--------------- TILE-62N090E: 2167 samlpes ---------------
#
# 		 ***0/2167
#
# 		--------------- TILE-74N141E: 0 samlpes ---------------
#
# 		--------------- TILE-74N120E: 2398 samlpes ---------------
#
# 		 ***0/2398
#
# 		--------------- TILE-60N165E: 0 samlpes ---------------
#
# 		--------------- TILE-70N105E: 36 samlpes ---------------
#
# 		 ***0/36
#
# 		--------------- TILE-60N102E: 23520 samlpes ---------------
#
# 		 ***0/23520
#
# 		--------------- TILE-62N129E: 20648 samlpes ---------------
#
# 		 ***0/20648
#
# 		--------------- TILE-64N090E: 0 samlpes ---------------
#
# 		--------------- TILE-70N093E: 44570 samlpes ---------------
#
# 		 ***0/44570
#
# 		--------------- TILE-62N144E: 246853 samlpes ---------------
#
# 		 ***0/246853
#
# 		--------------- TILE-70N144E: 7935 samlpes ---------------
#
# 		 ***0/7935
#
# 		--------------- TILE-70N108E: 26011 samlpes ---------------
#
# 		 ***0/26011
#
# 		--------------- TILE-66N156E: 316662 samlpes ---------------
#
# 		 ***0/316662
#
# 		--------------- TILE-62N072E: 21273 samlpes ---------------
#
# 		 ***0/21273
#
# 		--------------- TILE-66N126E: 2271 samlpes ---------------
#
# 		 ***0/2271
#
# 		--------------- TILE-72N096E: 0 samlpes ---------------
#
# 		--------------- TILE-62N132E: 1181831 samlpes ---------------
#
# 		 ***0/1181831
#
# 		 ***1000000/1181831
#
# 		--------------- TILE-64N102E: 11417 samlpes ---------------
#
# 		 ***0/11417
#
# 		--------------- TILE-74N111E: 0 samlpes ---------------
#
# 		--------------- TILE-70N135E: 8571 samlpes ---------------
#
# 		 ***0/8571
#
# 		--------------- TILE-72N138E: 0 samlpes ---------------
#
# 		--------------- TILE-66N066E: 165372 samlpes ---------------
#
# 		 ***0/165372
#
# 		--------------- TILE-74N087E: 0 samlpes ---------------
#
# 		--------------- TILE-66N147E: 6690 samlpes ---------------
#
# 		 ***0/6690
#
# 		--------------- TILE-70N111E: 13007 samlpes ---------------
#
# 		 ***0/13007
#
# 		--------------- TILE-60N159E: 2741 samlpes ---------------
#
# 		 ***0/2741
#
# 		--------------- TILE-64N114E: 335812 samlpes ---------------
#
# 		 ***0/335812
#
# 		--------------- TILE-68N171E: 5438 samlpes ---------------
#
# 		 ***0/5438
#
# 		--------------- TILE-70N171E: 146591 samlpes ---------------
#
# 		 ***0/146591
#
# 		--------------- TILE-70N132E: 8418 samlpes ---------------
#
# 		 ***0/8418
#
# 		--------------- TILE-64N159E: 2350 samlpes ---------------
#
# 		 ***0/2350
#
# 		--------------- TILE-66N132E: 17390 samlpes ---------------
#
# 		 ***0/17390
#
# 		--------------- TILE-60N126E: 156995 samlpes ---------------
#
# 		 ***0/156995
#
# 		--------------- TILE-60N099E: 51175 samlpes ---------------
#
# 		 ***0/51175
#
# 		--------------- TILE-68N099E: 13090 samlpes ---------------
#
# 		 ***0/13090
#
# 		--------------- TILE-62N078E: 5220 samlpes ---------------
#
# 		 ***0/5220
#
# 		--------------- TILE-60N144E: 0 samlpes ---------------
#
# 		--------------- TILE-62N102E: 93 samlpes ---------------
#
# 		 ***0/93
#
# 		--------------- TILE-60N069E: 1325 samlpes ---------------
#
# 		 ***0/1325
#
# 		 +++ BGCC: 11.565833082180943 Tg  //  CC: 11.651178135406482 Tg
#
#
# ++++++++++ Year 2022 is processed in 0.0 hours, 39.0 minutes, 53.013250999999855 seconds ++++++++++
#
#
# ########## Processing of Year: 2021 ##########
#
#
#
# 		--------------- TILE-68N132E: 114263 samlpes ---------------
#
# 		 ***0/114263
#
# 		--------------- TILE-60N111E: 117466 samlpes ---------------
#
# 		 ***0/117466
#
# 		--------------- TILE-70N123E: 27734 samlpes ---------------
#
# 		 ***0/27734
#
# 		--------------- TILE-70N141E: 188074 samlpes ---------------
#
# 		 ***0/188074
#
# 		--------------- TILE-60N108E: 2588151 samlpes ---------------
#
# 		 ***0/2588151
#
# 		 ***1000000/2588151
#
# 		 ***2000000/2588151
#
# 		--------------- TILE-70N177E: 1085 samlpes ---------------
#
# 		 ***0/1085
#
# 		--------------- TILE-70N075E: 421 samlpes ---------------
#
# 		 ***0/421
#
# 		--------------- TILE-62N111E: 996194 samlpes ---------------
#
# 		 ***0/996194
#
# 		--------------- TILE-68N084E: 0 samlpes ---------------
#
# 		--------------- TILE-66N090E: 0 samlpes ---------------
#
# 		--------------- TILE-64N117E: 13578452 samlpes ---------------
#
# 		 ***0/13578452
#
# 		 ***1000000/13578452
#
# 		 ***2000000/13578452
#
# 		 ***3000000/13578452
#
# 		 ***4000000/13578452
#
# 		 ***5000000/13578452
#
# 		 ***6000000/13578452
#
# 		 ***7000000/13578452
#
# 		 ***8000000/13578452
#
# 		 ***9000000/13578452
#
# 		 ***10000000/13578452
#
# 		 ***11000000/13578452
#
# 		 ***12000000/13578452
#
# 		 ***13000000/13578452
#
# 		--------------- TILE-62N093E: 361 samlpes ---------------
#
# 		 ***0/361
#
# 		--------------- TILE-72N117E: 0 samlpes ---------------
#
# 		--------------- TILE-72N105E: 0 samlpes ---------------
#
# 		--------------- TILE-70N126E: 22790 samlpes ---------------
#
# 		 ***0/22790
#
# 		--------------- TILE-62N153E: 565293 samlpes ---------------
#
# 		 ***0/565293
#
# 		--------------- TILE-62N165E: 2802421 samlpes ---------------
#
# 		 ***0/2802421
#
# 		 ***1000000/2802421
#
# 		 ***2000000/2802421
#
# 		--------------- TILE-64N120E: 9798378 samlpes ---------------
#
# 		 ***0/9798378
#
# 		 ***1000000/9798378
#
# 		 ***2000000/9798378
#
# 		 ***3000000/9798378
#
# 		 ***4000000/9798378
#
# 		 ***5000000/9798378
#
# 		 ***6000000/9798378
#
# 		 ***7000000/9798378
#
# 		 ***8000000/9798378
#
# 		 ***9000000/9798378
#
# 		--------------- TILE-70N078E: 0 samlpes ---------------
#
# 		--------------- TILE-60N093E: 11807 samlpes ---------------
#
# 		 ***0/11807
#
# 		--------------- TILE-70N066E: 161 samlpes ---------------
#
# 		 ***0/161
#
# 		--------------- TILE-64N126E: 40046664 samlpes ---------------
#
# 		 ***0/40046664
#
# 		 ***1000000/40046664
#
# 		 ***2000000/40046664
#
# 		 ***3000000/40046664
#
# 		 ***4000000/40046664
#
# 		 ***5000000/40046664
#
# 		 ***6000000/40046664
#
# 		 ***7000000/40046664
#
# 		 ***8000000/40046664
#
# 		 ***9000000/40046664
#
# 		 ***10000000/40046664
#
# 		 ***11000000/40046664
#
# 		 ***12000000/40046664
#
# 		 ***13000000/40046664
#
# 		 ***14000000/40046664
#
# 		 ***15000000/40046664
#
# 		 ***16000000/40046664
#
# 		 ***17000000/40046664
#
# 		 ***18000000/40046664
#
# 		 ***19000000/40046664
#
# 		 ***20000000/40046664
#
# 		 ***21000000/40046664
#
# 		 ***22000000/40046664
#
# 		 ***23000000/40046664
#
# 		 ***24000000/40046664
#
# 		 ***25000000/40046664
#
# 		 ***26000000/40046664
#
# 		 ***27000000/40046664
#
# 		 ***28000000/40046664
#
# 		 ***29000000/40046664
#
# 		 ***30000000/40046664
#
# 		 ***31000000/40046664
#
# 		 ***32000000/40046664
#
# 		 ***33000000/40046664
#
# 		 ***34000000/40046664
#
# 		 ***35000000/40046664
#
# 		 ***36000000/40046664
#
# 		 ***37000000/40046664
#
# 		 ***38000000/40046664
#
# 		 ***39000000/40046664
#
# 		 ***40000000/40046664
#
# 		--------------- TILE-68N117E: 1513812 samlpes ---------------
#
# 		 ***0/1513812
#
# 		 ***1000000/1513812
#
# 		--------------- TILE-64N096E: 4734 samlpes ---------------
#
# 		 ***0/4734
#
# ...
#
# 		 ***2000000/2628271
#
# 		--------------- TILE-74N093E: 0 samlpes ---------------
#
# 		--------------- TILE-66N153E: 3486603 samlpes ---------------
#
# 		 ***0/3486603
#
# 		 ***1000000/3486603
#
# 		 ***2000000/3486603
#
# 		 ***3000000/3486603
#
# 		--------------- TILE-64N084E: 6766 samlpes ---------------
#
# 		 ***0/6766
#
# 		--------------- TILE-60N090E: 100960 samlpes ---------------
#
# 		 ***0/100960
#
# 		--------------- TILE-68N090E: 0 samlpes ---------------
#
# 		--------------- TILE-74N096E: 0 samlpes ---------------
#
# 		--------------- TILE-64N144E: 508422 samlpes ---------------
#
# 		 ***0/508422
#
# 		--------------- TILE-68N177E: 4850 samlpes ---------------
#
# 		 ***0/4850
#
# 		--------------- TILE-64N066E: 38491 samlpes ---------------
#
# 		 ***0/38491
#
# 		--------------- TILE-72N090E: 0 samlpes ---------------
#
# 		--------------- TILE-72N144E: 0 samlpes ---------------
#
# 		--------------- TILE-72N150E: 0 samlpes ---------------
#
# 		--------------- TILE-62N171E: 0 samlpes ---------------
#
# 		--------------- TILE-66N177E: 6068 samlpes ---------------
#
# 		 ***0/6068
#
# 		--------------- TILE-60N138E: 9913 samlpes ---------------
#
# 		 ***0/9913
#
# 		--------------- TILE-66N162E: 743527 samlpes ---------------
#
# 		 ***0/743527
#
# 		--------------- TILE-68N135E: 9899584 samlpes ---------------
#
# 		 ***0/9899584
#
# 		 ***1000000/9899584
#
# 		 ***2000000/9899584
#
# 		 ***3000000/9899584
#
# 		 ***4000000/9899584
#
# 		 ***5000000/9899584
#
# 		 ***6000000/9899584
#
# 		 ***7000000/9899584
#
# 		 ***8000000/9899584
#
# 		 ***9000000/9899584
#
# 		--------------- TILE-74N123E: 0 samlpes ---------------
#
# 		--------------- TILE-60N096E: 41864 samlpes ---------------
#
# 		 ***0/41864
#
# 		--------------- TILE-64N147E: 96558 samlpes ---------------
#
# 		 ***0/96558
#
# 		--------------- TILE-66N174E: 29600 samlpes ---------------
#
# 		 ***0/29600
#
# 		--------------- TILE-68N093E: 0 samlpes ---------------
#
# 		--------------- TILE-60N072E: 0 samlpes ---------------
#
# 		--------------- TILE-64N174E: 0 samlpes ---------------
#
# 		--------------- TILE-72N069E: 0 samlpes ---------------
#
# 		--------------- TILE-74N147E: 0 samlpes ---------------
#
# 		--------------- TILE-66N087E: 6269 samlpes ---------------
#
# 		 ***0/6269
#
# 		--------------- TILE-70N114E: 35155 samlpes ---------------
#
# 		 ***0/35155
#
# 		--------------- TILE-70N099E: 0 samlpes ---------------
#
# 		--------------- TILE-74N102E: 0 samlpes ---------------
#
# 		--------------- TILE-66N171E: 163607 samlpes ---------------
#
# 		 ***0/163607
#
# 		--------------- TILE-70N096E: 0 samlpes ---------------
#
# 		--------------- TILE-68N162E: 3464050 samlpes ---------------
#
# 		 ***0/3464050
#
# 		 ***1000000/3464050
#
# 		 ***2000000/3464050
#
# 		 ***3000000/3464050
#
# 		--------------- TILE-60N120E: 982429 samlpes ---------------
#
# 		 ***0/982429
#
# 		--------------- TILE-72N108E: 0 samlpes ---------------
#
# 		--------------- TILE-68N078E: 6136 samlpes ---------------
#
# 		 ***0/6136
#
# 		--------------- TILE-64N153E: 350644 samlpes ---------------
#
# 		 ***0/350644
#
# 		--------------- TILE-66N105E: 117676 samlpes ---------------
#
# 		 ***0/117676
#
# 		--------------- TILE-70N090E: 0 samlpes ---------------
#
# 		--------------- TILE-68N108E: 15006 samlpes ---------------
#
# 		 ***0/15006
#
# 		--------------- TILE-74N132E: 0 samlpes ---------------
#
# 		--------------- TILE-62N087E: 74711 samlpes ---------------
#
# 		 ***0/74711
#
# 		--------------- TILE-64N171E: 45319 samlpes ---------------
#
# 		 ***0/45319
#
# 		--------------- TILE-64N132E: 3647430 samlpes ---------------
#
# 		 ***0/3647430
#
# 		 ***1000000/3647430
#
# 		 ***2000000/3647430
#
# 		 ***3000000/3647430
#
# 		--------------- TILE-68N120E: 2082553 samlpes ---------------
#
# 		 ***0/2082553
#
# 		 ***1000000/2082553
#
# 		 ***2000000/2082553
#
# 		--------------- TILE-68N153E: 5761207 samlpes ---------------
#
# 		 ***0/5761207
#
# 		 ***1000000/5761207
#
# 		 ***2000000/5761207
#
# 		 ***3000000/5761207
#
# 		 ***4000000/5761207
#
# 		 ***5000000/5761207
#
# 		--------------- TILE-68N063E: 34337 samlpes ---------------
#
# 		 ***0/34337
#
# 		--------------- TILE-66N120E: 705606 samlpes ---------------
#
# 		 ***0/705606
#
# 		--------------- TILE-72N093E: 0 samlpes ---------------
#
# 		--------------- TILE-60N117E: 135622 samlpes ---------------
#
# 		 ***0/135622
#
# 		--------------- TILE-66N081E: 0 samlpes ---------------
#
# 		--------------- TILE-64N093E: 1816 samlpes ---------------
#
# 		 ***0/1816
#
# 		--------------- TILE-70N147E: 4014932 samlpes ---------------
#
# 		 ***0/4014932
#
# 		 ***1000000/4014932
#
# 		 ***2000000/4014932
#
# 		 ***3000000/4014932
#
# 		 ***4000000/4014932
#
# 		--------------- TILE-72N066E: 0 samlpes ---------------
#
# 		--------------- TILE-70N069E: 0 samlpes ---------------
#
# 		--------------- TILE-64N177E: 0 samlpes ---------------
#
# 		--------------- TILE-62N150E: 134756 samlpes ---------------
#
# 		 ***0/134756
#
# 		--------------- TILE-62N162E: 0 samlpes ---------------
#
# 		--------------- TILE-68N156E: 644396 samlpes ---------------
#
# 		 ***0/644396
#
# 		--------------- TILE-60N078E: 453631 samlpes ---------------
#
# 		 ***0/453631
#
# 		--------------- TILE-66N075E: 21923 samlpes ---------------
#
# 		 ***0/21923
#
# 		--------------- TILE-66N123E: 6015756 samlpes ---------------
#
# 		 ***0/6015756
#
# 		 ***1000000/6015756
#
# 		 ***2000000/6015756
#
# 		 ***3000000/6015756
#
# 		 ***4000000/6015756
#
# 		 ***5000000/6015756
#
# 		 ***6000000/6015756
#
# 		--------------- TILE-60N075E: 91165 samlpes ---------------
#
# 		 ***0/91165
#
# 		--------------- TILE-66N072E: 124857 samlpes ---------------
#
# 		 ***0/124857
#
# 		--------------- TILE-70N081E: 13854 samlpes ---------------
#
# 		 ***0/13854
#
# 		--------------- TILE-68N141E: 2326672 samlpes ---------------
#
# 		 ***0/2326672
#
# 		 ***1000000/2326672
#
# 		 ***2000000/2326672
#
# 		--------------- TILE-66N108E: 26171 samlpes ---------------
#
# 		 ***0/26171
#
# 		--------------- TILE-66N144E: 510207 samlpes ---------------
#
# 		 ***0/510207
#
# 		--------------- TILE-66N129E: 835950 samlpes ---------------
#
# 		 ***0/835950
#
# 		--------------- TILE-68N087E: 0 samlpes ---------------
#
# 		--------------- TILE-70N102E: 0 samlpes ---------------
#
# 		--------------- TILE-68N081E: 14608 samlpes ---------------
#
# 		 ***0/14608
#
# 		--------------- TILE-60N063E: 82250 samlpes ---------------
#
# 		 ***0/82250
#
# 		--------------- TILE-62N135E: 32811 samlpes ---------------
#
# 		 ***0/32811
#
# 		--------------- TILE-66N135E: 2992740 samlpes ---------------
#
# 		 ***0/2992740
#
# 		 ***1000000/2992740
#
# 		 ***2000000/2992740
#
# 		--------------- TILE-68N096E: 0 samlpes ---------------
#
# 		--------------- TILE-72N141E: 285855 samlpes ---------------
#
# 		 ***0/285855
#
# 		--------------- TILE-74N069E: 0 samlpes ---------------
#
# 		--------------- TILE-64N081E: 0 samlpes ---------------
#
# 		--------------- TILE-68N075E: 28516 samlpes ---------------
#
# 		 ***0/28516
#
# 		--------------- TILE-62N156E: 386 samlpes ---------------
#
# 		 ***0/386
#
# 		--------------- TILE-60N084E: 18255 samlpes ---------------
#
# 		 ***0/18255
#
# 		--------------- TILE-60N114E: 692003 samlpes ---------------
#
# 		 ***0/692003
#
# 		--------------- TILE-66N063E: 25937 samlpes ---------------
#
# 		 ***0/25937
#
# 		--------------- TILE-72N114E: 0 samlpes ---------------
#
# 		--------------- TILE-72N072E: 0 samlpes ---------------
#
# 		--------------- TILE-60N135E: 94284 samlpes ---------------
#
# 		 ***0/94284
#
# 		--------------- TILE-64N123E: 4743729 samlpes ---------------
#
# 		 ***0/4743729
#
# 		 ***1000000/4743729
#
# 		 ***2000000/4743729
#
# 		 ***3000000/4743729
#
# 		 ***4000000/4743729
#
# 		--------------- TILE-64N072E: 9863 samlpes ---------------
#
# 		 ***0/9863
#
# 		--------------- TILE-64N165E: 665283 samlpes ---------------
#
# 		 ***0/665283
#
# 		--------------- TILE-74N114E: 0 samlpes ---------------
#
# 		--------------- TILE-72N132E: 415808 samlpes ---------------
#
# 		 ***0/415808
#
# 		--------------- TILE-68N111E: 173716 samlpes ---------------
#
# 		 ***0/173716
#
# 		--------------- TILE-64N111E: 173807 samlpes ---------------
#
# 		 ***0/173807
#
# 		--------------- TILE-68N138E: 527128 samlpes ---------------
#
# 		 ***0/527128
#
# 		--------------- TILE-70N162E: 37371 samlpes ---------------
#
# 		 ***0/37371
#
# 		--------------- TILE-72N147E: 0 samlpes ---------------
#
# 		--------------- TILE-72N075E: 0 samlpes ---------------
#
# 		--------------- TILE-72N099E: 0 samlpes ---------------
#
# 		--------------- TILE-68N114E: 1211740 samlpes ---------------
#
# 		 ***0/1211740
#
# 		 ***1000000/1211740
#
# 		--------------- TILE-62N105E: 23538 samlpes ---------------
#
# 		 ***0/23538
#
# 		--------------- TILE-74N129E: 0 samlpes ---------------
#
# 		--------------- TILE-70N168E: 0 samlpes ---------------
#
# 		--------------- TILE-66N159E: 4352589 samlpes ---------------
#
# 		 ***0/4352589
#
# 		 ***1000000/4352589
#
# 		 ***2000000/4352589
#
# 		 ***3000000/4352589
#
# 		 ***4000000/4352589
#
# 		--------------- TILE-66N084E: 0 samlpes ---------------
#
# 		--------------- TILE-68N072E: 234 samlpes ---------------
#
# 		 ***0/234
#
# 		--------------- TILE-66N138E: 423748 samlpes ---------------
#
# 		 ***0/423748
#
# 		--------------- TILE-66N093E: 11551 samlpes ---------------
#
# 		 ***0/11551
#
# 		--------------- TILE-68N102E: 0 samlpes ---------------
#
# 		--------------- TILE-62N117E: 1062393 samlpes ---------------
#
# 		 ***0/1062393
#
# 		 ***1000000/1062393
#
# 		--------------- TILE-60N162E: 16 samlpes ---------------
#
# 		 ***0/16
#
# 		--------------- TILE-66N114E: 645390 samlpes ---------------
#
# 		 ***0/645390
#
# 		--------------- TILE-72N135E: 0 samlpes ---------------
#
# 		--------------- TILE-64N075E: 17149 samlpes ---------------
#
# 		 ***0/17149
#
# 		--------------- TILE-72N126E: 0 samlpes ---------------
#
# 		--------------- TILE-62N174E: 0 samlpes ---------------
#
# 		--------------- TILE-66N102E: 11841 samlpes ---------------
#
# 		 ***0/11841
#
# 		--------------- TILE-70N174E: 0 samlpes ---------------
#
# 		--------------- TILE-60N153E: 253775 samlpes ---------------
#
# 		 ***0/253775
#
# 		--------------- TILE-72N120E: 96455 samlpes ---------------
#
# 		 ***0/96455
#
# 		--------------- TILE-74N072E: 0 samlpes ---------------
#
# 		--------------- TILE-68N168E: 404 samlpes ---------------
#
# 		 ***0/404
#
# 		--------------- TILE-74N135E: 0 samlpes ---------------
#
# 		--------------- TILE-72N102E: 0 samlpes ---------------
#
# 		--------------- TILE-70N063E: 36 samlpes ---------------
#
# 		 ***0/36
#
# 		--------------- TILE-72N123E: 1664127 samlpes ---------------
#
# 		 ***0/1664127
#
# 		 ***1000000/1664127
#
# 		--------------- TILE-74N144E: 0 samlpes ---------------
#
# 		--------------- TILE-72N153E: 0 samlpes ---------------
#
# 		--------------- TILE-74N117E: 0 samlpes ---------------
#
# 		--------------- TILE-68N159E: 155833 samlpes ---------------
#
# 		 ***0/155833
#
# 		--------------- TILE-74N126E: 0 samlpes ---------------
#
# 		--------------- TILE-74N066E: 0 samlpes ---------------
#
# 		--------------- TILE-64N156E: 305251 samlpes ---------------
#
# 		 ***0/305251
#
# 		--------------- TILE-66N078E: 674 samlpes ---------------
#
# 		 ***0/674
#
# 		--------------- TILE-68N165E: 151658 samlpes ---------------
#
# 		 ***0/151658
#
# 		--------------- TILE-70N120E: 10139 samlpes ---------------
#
# 		 ***0/10139
#
# 		--------------- TILE-62N081E: 110686 samlpes ---------------
#
# 		 ***0/110686
#
# 		--------------- TILE-60N105E: 48779 samlpes ---------------
#
# 		 ***0/48779
#
# 		--------------- TILE-70N129E: 536079 samlpes ---------------
#
# 		 ***0/536079
#
# 		--------------- TILE-72N156E: 0 samlpes ---------------
#
# 		--------------- TILE-62N114E: 884168 samlpes ---------------
#
# 		 ***0/884168
#
# 		--------------- TILE-66N141E: 410318 samlpes ---------------
#
# 		 ***0/410318
#
# 		--------------- TILE-62N075E: 24164 samlpes ---------------
#
# 		 ***0/24164
#
# 		--------------- TILE-70N117E: 23309 samlpes ---------------
#
# 		 ***0/23309
#
# 		--------------- TILE-62N168E: 48 samlpes ---------------
#
# 		 ***0/48
#
# 		--------------- TILE-60N087E: 49283 samlpes ---------------
#
# 		 ***0/49283
#
# 		--------------- TILE-70N150E: 411677 samlpes ---------------
#
# 		 ***0/411677
#
# 		--------------- TILE-70N084E: 0 samlpes ---------------
#
# 		--------------- TILE-74N090E: 0 samlpes ---------------
#
# 		--------------- TILE-66N165E: 812689 samlpes ---------------
#
# 		 ***0/812689
#
# 		--------------- TILE-74N075E: 0 samlpes ---------------
#
# 		--------------- TILE-62N141E: 25080 samlpes ---------------
#
# 		 ***0/25080
#
# 		--------------- TILE-74N084E: 0 samlpes ---------------
#
# 		--------------- TILE-62N063E: 34345 samlpes ---------------
#
# 		 ***0/34345
#
# 		--------------- TILE-60N147E: 257360 samlpes ---------------
#
# 		 ***0/257360
#
# 		--------------- TILE-68N123E: 202495 samlpes ---------------
#
# 		 ***0/202495
#
# 		--------------- TILE-62N069E: 4797 samlpes ---------------
#
# 		 ***0/4797
#
# 		--------------- TILE-62N096E: 0 samlpes ---------------
#
# 		--------------- TILE-62N090E: 15675 samlpes ---------------
#
# 		 ***0/15675
#
# 		--------------- TILE-74N141E: 0 samlpes ---------------
#
# 		--------------- TILE-74N120E: 0 samlpes ---------------
#
# 		--------------- TILE-60N165E: 0 samlpes ---------------
#
# 		--------------- TILE-70N105E: 79815 samlpes ---------------
#
# 		 ***0/79815
#
# 		--------------- TILE-60N102E: 631975 samlpes ---------------
#
# 		 ***0/631975
#
# 		--------------- TILE-62N129E: 803707 samlpes ---------------
#
# 		 ***0/803707
#
# 		--------------- TILE-64N090E: 428 samlpes ---------------
#
# 		 ***0/428
#
# 		--------------- TILE-70N093E: 0 samlpes ---------------
#
# 		--------------- TILE-62N144E: 206567 samlpes ---------------
#
# 		 ***0/206567
#
# 		--------------- TILE-70N144E: 157219 samlpes ---------------
#
# 		 ***0/157219
#
# 		--------------- TILE-70N108E: 19959 samlpes ---------------
#
# 		 ***0/19959
#
# 		--------------- TILE-66N156E: 11346420 samlpes ---------------
#
# 		 ***0/11346420
#
# 		 ***1000000/11346420
#
# 		 ***2000000/11346420
#
# 		 ***3000000/11346420
#
# 		 ***4000000/11346420
#
# 		 ***5000000/11346420
#
# 		 ***6000000/11346420
#
# 		 ***7000000/11346420
#
# 		 ***8000000/11346420
#
# 		 ***9000000/11346420
#
# 		 ***10000000/11346420
#
# 		 ***11000000/11346420
#
# 		--------------- TILE-62N072E: 31519 samlpes ---------------
#
# 		 ***0/31519
#
# 		--------------- TILE-66N126E: 1637720 samlpes ---------------
#
# 		 ***0/1637720
#
# 		 ***1000000/1637720
#
# 		--------------- TILE-72N096E: 0 samlpes ---------------
#
# 		--------------- TILE-62N132E: 75006 samlpes ---------------
#
# 		 ***0/75006
#
# 		--------------- TILE-64N102E: 1261 samlpes ---------------
#
# 		 ***0/1261
#
# 		--------------- TILE-74N111E: 0 samlpes ---------------
#
# 		--------------- TILE-70N135E: 778520 samlpes ---------------
#
# 		 ***0/778520
#
# 		--------------- TILE-72N138E: 0 samlpes ---------------
#
# 		--------------- TILE-66N066E: 21046 samlpes ---------------
#
# 		 ***0/21046
#
# 		--------------- TILE-74N087E: 0 samlpes ---------------
#
# 		--------------- TILE-66N147E: 333270 samlpes ---------------
#
# 		 ***0/333270
#
# 		--------------- TILE-70N111E: 150565 samlpes ---------------
#
# 		 ***0/150565
#
# 		--------------- TILE-60N159E: 159964 samlpes ---------------
#
# 		 ***0/159964
#
# 		--------------- TILE-64N114E: 46831 samlpes ---------------
#
# 		 ***0/46831
#
# 		--------------- TILE-68N171E: 986 samlpes ---------------
#
# 		 ***0/986
#
# 		--------------- TILE-70N171E: 4741 samlpes ---------------
#
# 		 ***0/4741
#
# 		--------------- TILE-70N132E: 3941232 samlpes ---------------
#
# 		 ***0/3941232
#
# 		 ***1000000/3941232
#
# 		 ***2000000/3941232
#
# 		 ***3000000/3941232
#
# 		--------------- TILE-64N159E: 384998 samlpes ---------------
#
# 		 ***0/384998
#
# 		--------------- TILE-66N132E: 771051 samlpes ---------------
#
# 		 ***0/771051
#
# 		--------------- TILE-60N126E: 38827 samlpes ---------------
#
# 		 ***0/38827
#
# 		--------------- TILE-60N099E: 38974 samlpes ---------------
#
# 		 ***0/38974
#
# 		--------------- TILE-68N099E: 0 samlpes ---------------
#
# 		--------------- TILE-62N078E: 18496 samlpes ---------------
#
# 		 ***0/18496
#
# 		--------------- TILE-60N144E: 51726 samlpes ---------------
#
# 		 ***0/51726
#
# 		--------------- TILE-62N102E: 10674 samlpes ---------------
#
# 		 ***0/10674
#
# 		--------------- TILE-60N069E: 5383 samlpes ---------------
#
# 		 ***0/5383
#
# 		 +++ BGCC: 30.80086720665328 Tg  //  CC: 31.02525724880085 Tg
#
#
# ++++++++++ Year 2001 is processed in 2.0 hours, 0.0 minutes, 11.494909000000007 seconds ++++++++++
#
#
# -------------------- FINISHED in 41.0 hours, 8.0 minutes, 4.9341199999907985 seconds --------------------

# %%
with open(f'{local_path}/PeatFire/Logs/Logfile_PeatFire_Emissions_Uncertainty.txt', 'r') as file:
    text = file.read()

# %%
df = {}
p_BGCC = re.escape('BGCC: ') + r"(.*?)" + re.escape(' Tg')
p_ALL = re.escape('ALL: ') + r"(.*?)" + re.escape(' Tg')
df['BGCC'] = [float(i) for i in re.findall(p_BGCC, text)]
df['ALL'] = [float(i) for i in re.findall(p_ALL, text)]
df = pd.DataFrame(df, index=list(Years)).reset_index().rename(columns={'index': 'Year'})
df = df.sort_values('Year').reset_index().drop(columns='index')
df
# Out:
#     Year       BGCC        ALL
# 0   2001  17.180353  17.305469
# 1   2002  18.713177  18.849456
# 2   2003  21.630151  21.787673
# 3   2004   5.944071   5.987359
# 4   2005  13.270894  13.367539
# 5   2006  13.192248  13.288320
# 6   2007   5.961049   6.004460
# 7   2008   9.017601   9.083271
# 8   2009  13.312948  13.409899
# 9   2010  13.995372  14.097293
# 10  2011  14.295001  14.399105
# 11  2012  23.691237  23.863769
# 12  2013  16.375272  16.494525
# 13  2014  11.991485  12.078813
# 14  2015   2.495055   2.513226
# 15  2016  17.389211  17.515848
# 16  2017   9.463875   9.532796
# 17  2018  16.717943  16.839692
# 18  2019  23.811185  23.984590
# 19  2020  27.495553  27.695790
# 20  2021  26.414853  26.607220
# 21  2022   7.210187   7.262695
# 22  2023  10.700601  10.778528

# %%
df.to_csv(f'{local_path}/PeatFire/BG_CC/data/Siberia_Yearly_Emissions_Uncertainty.csv', index=False)
